# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img
#  src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/alx-courses/aice/assets/Content_page_banner_blue_dots.png"
#  alt="ALX Content Header"
#  class="full-width-image"
# />
# </div>

# %% [markdown]
# # Subquery in the JOIN clause

# %% [markdown]
# In this notebook we will look at subqueries, which are powerful tools to enable more in-depth analysis in SQL. They are essentially intermediate results sets that we access with another query, so **a query inside another query**. We can use subqueries in various places in a query, and those subquery results also have various forms. Here, we look at the **use of a subquery in the `JOIN` clause.**

# %% [markdown]
# > ⚠️ This notebook will not run on Google Colab because it cannot connect to a local database. Please make sure that this notebook is running on the same local machine as your MySQL Workbench installation and MySQL `united_nations` database.

# %% [markdown]
# ## Learning objectives
#
# In this train, we will learn:
# - How to use the result set of a subquery in the main query by joining the main table to the subquery on a related column.

# %% [markdown]
# ## Overview
#
# Imagine we want to calculate the percentage of land area that a specific country in a sub-region occupies, as a percentage of the total land area in that sub-region. We would need to divide each country’s land area with the sum of all countries in that sub-region.
#
# Previously, we created a correlated subquery that calculated the land area for each row. Let’s improve on that. It would be more efficient if we calculated the total land area once for each sub-region. **We can then run a query that would just retrieve the land area value from the result of the inner query.**

# %% [markdown]
# ## Connecting to our MySQL database
#
# We will use our `Geographic_location` table in our `united_nations` database that we created in MySQL Workbench. We can apply the same queries we used in MySQL Workbench in this notebook if we connect to our MySQL server by running the cells below.

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook. 
# If you get an error here, make sure that mysql and pymysql are installed correctly. 

# %load_ext sql

# %%
# Establish a connection to the local database using the '%sql' magic command.
# Replace 'password' with our connection password and `db_name` with our database name. 
# If you get an error here, please make sure the database name or password is correct.

# %sql mysql+pymysql://root:Innovator1@localhost:3306/united_nations
# Out:
# 'Connected: root@united_nations'

# %%
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'

# %% [markdown]
# ## Exercise

# %% [markdown]
# ### 1. Calculate the total land area for each sub-region
#
# Write a query that will aggregate the data by summing the `land area` and then grouping the sums by `sub-region`. Give the sums the alias `TotalLandArea`.

# %%
# %%sql
#
# SELECT
#     Sub_region,
# 	SUM(Land_area) AS TotalLandArea
# FROM
#     Geographic_location
# GROUP BY
# 	Sub_region;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 18 rows affected.
# [('Southern Asia', Decimal('4770135.41')),
#  ('Northern Africa', Decimal('6610941.00')),
#  ('Polynesia', Decimal('7217.67')),
#  ('Middle Africa', Decimal('3888270.00')),
#  ('Caribbean', Decimal('208104.00')),
#  ('South America', Decimal('15401392.00')),
#  ('Western Asia', Decimal('3488571.67')),
#  ('Australia and New Zealand', Decimal('7953710.00')),
#  ('Central America', Decimal('2452080.00')),
#  ('Western Africa', Decimal('5735548.83')),
#  ('Northern America', Decimal('9376094.00')),
#  ('Southern Africa', Decimal('2650670.00')),
#  ('South-Eastern Asia', Decimal('3865282.00')),
#  ('Eastern Africa', Decimal('5949153.16')),
#  ('Eastern Asia', Decimal('11346499.57')),
#  ('Melanesia', Decimal('529590.00')),
#  ('Micronesia', Decimal('2470.00')),
#  ('Central Asia', Decimal('3749015.17'))]

# %% [markdown]
# ### 2. Calculate country land area percentages for all the regions using a subquery in the JOIN clause
#
# Create a query with a main query that selects, from the `Geographic_location` table, the columns `Country_name`, `Land_area`, and `Sub_region`. The next line should then divide the `Land area` by the land area totals named, `TotalLandArea`, gotten from the subquery. Give this calculated column the alias `Pct_of_region_land`.
#
# The query should also have a `JOIN` clause where we will add the query we created in Exercise 1 as a subquery named `Land_per_region`. This join occurs between the `Geographic_location` table and the `Land_per_region` subquery on the `Sub_region` column.

# %%
# %%sql
#
# SELECT
#     g.Country_name,
#     g.Sub_region,
#     g.Land_area,
# 	ROUND((g.Land_area / (Land_per_region.TotalLandArea)) * 100, 2) AS pct_regional_land
# FROM
#     Geographic_location g
# JOIN
#     (
#         SELECT
#             Sub_region,
#             SUM(Land_area) AS TotalLandArea
#         FROM
#             Geographic_location
#         GROUP BY
#             Sub_region
#     ) AS Land_per_region
# ON
#    g.Sub_region = Land_per_region.Sub_region;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 182 rows affected.
# [('Afghanistan', 'Southern Asia', Decimal('652230.00'), Decimal('13.67')),
#  ('Algeria', 'Northern Africa', Decimal('2381741.00'), Decimal('36.03')),
#  ('American Samoa', 'Polynesia', Decimal('200.00'), Decimal('2.77')),
#  ('Angola', 'Middle Africa', Decimal('1246700.00'), Decimal('32.06')),
#  ('Anguilla', 'Caribbean', None, None),
#  ('Antigua and Barbuda', 'Caribbean', Decimal('440.00'), Decimal('0.21')),
#  ('Argentina', 'South America', Decimal('2736690.00'), Decimal('17.77')),
#  ('Armenia', 'Western Asia', Decimal('28470.00'), Decimal('0.82')),
#  ('Aruba', 'Caribbean', Decimal('180.00'), Decimal('0.09')),
#  ('Australia', 'Australia and New Zealand', Decimal('7690400.00'), Decimal('96.69')),
#  ('Azerbaijan', 'Western Asia', Decimal('82658.17'), Decimal('2.37')),
#  ('Bahamas', 'Caribbean', None, None),
#  ('Bahrain', 'Western Asia', Decimal('780.83'), Decimal('0.02')),
#  ('Bangladesh', 'Southern Asia', Decimal('130170.00'), Decimal('2.73')),
#  ('Barbados', 'Caribbean', Decimal('430.00'), Decimal('0.21')),
#  ('Belize', 'Central America', Decimal('22810.00'), Decimal('0.93')),
#  ('Benin', 'Western Africa', Decimal('112760.00'), Decimal('1.97')),
#  ('Bermuda', 'Northern America', Decimal('54.00'), Decimal('0.00')),
#  ('Bhutan', 'Southern Asia', Decimal('38137.50'), Decimal('0.80')),
#  ('Bolivia (Plurinational State of)', 'South America', None, None),
#  ('Botswana', 'Southern Africa', Decimal('566730.00'), Decimal('21.38')),
#  ('Brazil', 'South America', Decimal('8358140.00'), Decimal('54.27')),
#  ('British Virgin Islands', 'Caribbean', Decimal('150.00'), Decimal('0.07')),
#  ('Brunei Darussalam', 'South-Eastern Asia', Decimal('5270.00'), Decimal('0.14')),
#  ('Burkina Faso', 'Western Africa', Decimal('273600.00'), Decimal('4.77')),
#  ('Burundi', 'Eastern Africa', Decimal('25680.00'), Decimal('0.43')),
#  ('Cabo Verde', 'Western Africa', Decimal('4030.00'), Decimal('0.07')),
#  ('Cambodia', 'South-Eastern Asia', Decimal('176520.00'), Decimal('4.57')),
#  ('Cameroon', 'Middle Africa', Decimal('472710.00'), Decimal('12.16')),
#  ('Canada', 'Northern America', Decimal('8965590.00'), Decimal('95.62')),
#  ('Cayman Islands', 'Caribbean', Decimal('240.00'), Decimal('0.12')),
#  ('Central African Republic', 'Middle Africa', Decimal('622980.00'), Decimal('16.02')),
#  ('Chad', 'Middle Africa', Decimal('1259200.00'), Decimal('32.38')),
#  ('Chile', 'South America', Decimal('743532.00'), Decimal('4.83')),
#  ('China', 'Eastern Asia', Decimal('9424701.90'), Decimal('83.06')),
#  ('Colombia', 'South America', Decimal('1109500.00'), Decimal('7.20')),
#  ('Comoros', 'Eastern Africa', Decimal('1861.00'), Decimal('0.03')),
#  ('Congo', 'Middle Africa', None, None),
#  ('Cook Islands', 'Polynesia', None, None),
#  ('Costa Rica', 'Central America', Decimal('51060.00'), Decimal('2.08')),
#  ("Côte d'Ivoire", 'Western Africa', None, None),
#  ('Cuba', 'Caribbean', Decimal('103890.00'), Decimal('49.92')),
#  ('Curaçao', 'Caribbean', None, None),
#  ('Cyprus', 'Western Asia', Decimal('9240.00'), Decimal('0.26')),
#  ("Democratic People's Republic of Korea", 'Eastern Asia', None, None),
#  ('Democratic Republic of the Congo', 'Middle Africa', None, None),
#  ('Djibouti', 'Eastern Africa', Decimal('23180.00'), Decimal('0.39')),
#  ('Dominica', 'Caribbean', Decimal('750.00'), Decimal('0.36')),
#  ('Dominican Republic', 'Caribbean', Decimal('48310.00'), Decimal('23.21')),
#  ('Ecuador', 'South America', Decimal('248360.00'), Decimal('1.61')),
#  ('Egypt', 'Northern Africa', None, None),
#  ('El Salvador', 'Central America', Decimal('20720.00'), Decimal('0.84')),
#  ('Equatorial Guinea', 'Middle Africa', Decimal('28050.00'), Decimal('0.72')),
#  ('Eritrea', 'Eastern Africa', Decimal('121083.12'), Decimal('2.04')),
#  ('Eswatini', 'Southern Africa', Decimal('17200.00'), Decimal('0.65')),
#  ('Ethiopia', 'Eastern Africa', Decimal('1128559.04'), Decimal('18.97')),
#  ('Falkland Islands (Malvinas)', 'South America', None, None),
#  ('Fiji', 'Melanesia', Decimal('18270.00'), Decimal('3.45')),
#  ('French Guiana', 'South America', None, None),
#  ('French Polynesia', 'Polynesia', Decimal('3471.00'), Decimal('48.09')),
#  ('Gabon', 'Middle Africa', Decimal('257670.00'), Decimal('6.63')),
#  ('Gambia', 'Western Africa', None, None),
#  ('Georgia', 'Western Asia', Decimal('69490.00'), Decimal('1.99')),
#  ('Ghana', 'Western Africa', Decimal('227538.83'), Decimal('3.97')),
#  ('Greenland', 'Northern America', Decimal('410450.00'), Decimal('4.38')),
#  ('Grenada', 'Caribbean', Decimal('340.00'), Decimal('0.16')),
#  ('Guadeloupe', 'Caribbean', None, None),
#  ('Guam', 'Micronesia', Decimal('540.00'), Decimal('21.86')),
#  ('Guatemala', 'Central America', Decimal('107160.00'), Decimal('4.37')),
#  ('Guinea', 'Western Africa', Decimal('245720.00'), Decimal('4.28')),
#  ('Guinea-Bissau', 'Western Africa', Decimal('28120.00'), Decimal('0.49')),
#  ('Guyana', 'South America', Decimal('196850.00'), Decimal('1.28')),
#  ('Haiti', 'Caribbean', Decimal('27560.00'), Decimal('13.24')),
#  ('Honduras', 'Central America', Decimal('111890.00'), Decimal('4.56')),
#  ('India', 'Southern Asia', Decimal('2973190.00'), Decimal('62.33')),
#  ('Indonesia', 'South-Eastern Asia', Decimal('1877519.00'), Decimal('48.57')),
#  ('Iran (Islamic Republic of)', 'Southern Asia', None, None),
#  ('Iraq', 'Western Asia', Decimal('434128.00'), Decimal('12.44')),
#  ('Israel', 'Western Asia', Decimal('21640.00'), Decimal('0.62')),
#  ('Jamaica', 'Caribbean', Decimal('10830.00'), Decimal('5.20')),
#  ('Japan', 'Eastern Asia', Decimal('364500.00'), Decimal('3.21')),
#  ('Jordan', 'Western Asia', Decimal('88784.67'), Decimal('2.55')),
#  ('Kazakhstan', 'Central Asia', Decimal('2699700.00'), Decimal('72.01')),
#  ('Kenya', 'Eastern Africa', Decimal('569140.00'), Decimal('9.57')),
#  ('Kiribati', 'Micronesia', Decimal('810.00'), Decimal('32.79')),
#  ('Kuwait', 'Western Asia', Decimal('17820.00'), Decimal('0.51')),
#  ('Kyrgyzstan', 'Central Asia', None, None),
#  ("Lao People's Democratic Republic", 'South-Eastern Asia', None, None),
#  ('Lebanon', 'Western Asia', Decimal('10230.00'), Decimal('0.29')),
#  ('Lesotho', 'Southern Africa', Decimal('30360.00'), Decimal('1.15')),
#  ('Liberia', 'Western Africa', Decimal('96320.00'), Decimal('1.68')),
#  ('Libya', 'Northern Africa', Decimal('1759540.00'), Decimal('26.62')),
#  ('Madagascar', 'Eastern Africa', Decimal('581800.00'), Decimal('9.78')),
#  ('Malawi', 'Eastern Africa', Decimal('94280.00'), Decimal('1.58')),
#  ('Malaysia', 'South-Eastern Asia', Decimal('328550.00'), Decimal('8.50')),
#  ('Maldives', 'Southern Asia', Decimal('300.00'), Decimal('0.01')),
#  ('Mali', 'Western Africa', Decimal('1220190.00'), Decimal('21.27')),
#  ('Marshall Islands', 'Micronesia', Decimal('180.00'), Decimal('7.29')),
#  ('Martinique', 'Caribbean', None, None),
#  ('Mauritania', 'Western Africa', Decimal('1030700.00'), Decimal('17.97')),
#  ('Mauritius', 'Eastern Africa', Decimal('2030.00'), Decimal('0.03')),
#  ('Mayotte', 'Eastern Africa', None, None),
#  ('Mexico', 'Central America', Decimal('1943950.00'), Decimal('79.28')),
#  ('Micronesia (Federated States of)', 'Micronesia', None, None),
#  ('Mongolia', 'Eastern Asia', Decimal('1557297.67'), Decimal('13.72')),
#  ('Montserrat', 'Caribbean', None, None),
#  ('Morocco', 'Northern Africa', Decimal('446300.00'), Decimal('6.75')),
#  ('Mozambique', 'Eastern Africa', Decimal('786380.00'), Decimal('13.22')),
#  ('Myanmar', 'South-Eastern Asia', Decimal('652780.00'), Decimal('16.89')),
#  ('Namibia', 'Southern Africa', Decimal('823290.00'), Decimal('31.06')),
#  ('Nauru', 'Micronesia', Decimal('20.00'), Decimal('0.81')),
#  ('Nepal', 'Southern Asia', Decimal('143350.00'), Decimal('3.01')),
#  ('New Caledonia', 'Melanesia', Decimal('18280.00'), Decimal('3.45')),
#  ('New Zealand', 'Australia and New Zealand', Decimal('263310.00'), Decimal('3.31')),
#  ('Nicaragua', 'Central America', Decimal('120340.00'), Decimal('4.91')),
#  ('Niger', 'Western Africa', Decimal('1266700.00'), Decimal('22.09')),
#  ('Nigeria', 'Western Africa', Decimal('910770.00'), Decimal('15.88')),
#  ('Niue', 'Polynesia', None, None),
#  ('Northern Mariana Islands', 'Micronesia', Decimal('460.00'), Decimal('18.62')),
#  ('Oman', 'Western Asia', Decimal('309500.00'), Decimal('8.87')),
#  ('Pakistan', 'Southern Asia', Decimal('770880.00'), Decimal('16.16')),
#  ('Palau', 'Micronesia', Decimal('460.00'), Decimal('18.62')),
#  ('Panama', 'Central America', Decimal('74150.00'), Decimal('3.02')),
#  ('Papua New Guinea', 'Melanesia', Decimal('452860.00'), Decimal('85.51')),
#  ('Paraguay', 'South America', Decimal('397300.00'), Decimal('2.58')),
#  ('Peru', 'South America', Decimal('1280000.00'), Decimal('8.31')),
#  ('Philippines', 'South-Eastern Asia', Decimal('298170.00'), Decimal('7.71')),
#  ('Puerto Rico', 'Caribbean', Decimal('8870.00'), Decimal('4.26')),
#  ('Qatar', 'Western Asia', Decimal('11490.00'), Decimal('0.33')),
#  ('Republic of Korea', 'Eastern Asia', None, None),
#  ('Réunion', 'Eastern Africa', None, None),
#  ('Rwanda', 'Eastern Africa', Decimal('24670.00'), Decimal('0.41')),
#  ('Saint Barthélemy', 'Caribbean', None, None),
#  ('Saint Helena', 'Western Africa', None, None),
#  ('Saint Kitts and Nevis', 'Caribbean', None, None),
#  ('Saint Lucia', 'Caribbean', None, None),
#  ('Saint Martin (French Part)', 'Caribbean', None, None),
#  ('Saint Pierre and Miquelon', 'Northern America', None, None),
#  ('Saint Vincent and the Grenadines', 'Caribbean', None, None),
#  ('Samoa', 'Polynesia', Decimal('2796.67'), Decimal('38.75')),
#  ('Sao Tome and Principe', 'Middle Africa', Decimal('960.00'), Decimal('0.02')),
#  ('Saudi Arabia', 'Western Asia', Decimal('2149690.00'), Decimal('61.62')),
#  ('Senegal', 'Western Africa', Decimal('192530.00'), Decimal('3.36')),
#  ('Seychelles', 'Eastern Africa', Decimal('460.00'), Decimal('0.01')),
#  ('Sierra Leone', 'Western Africa', Decimal('72180.00'), Decimal('1.26')),
#  ('Singapore', 'South-Eastern Asia', Decimal('713.00'), Decimal('0.02')),
#  ('Sint Maarten (Dutch part)', 'Caribbean', Decimal('34.00'), Decimal('0.02')),
#  ('Solomon Islands', 'Melanesia', Decimal('27990.00'), Decimal('5.29')),
#  ('Somalia', 'Eastern Africa', Decimal('627340.00'), Decimal('10.55')),
#  ('South Africa', 'Southern Africa', Decimal('1213090.00'), Decimal('45.77')),
#  ('South Sudan', 'Eastern Africa', Decimal('631930.00'), Decimal('10.62')),
#  ('Sri Lanka', 'Southern Asia', Decimal('61877.91'), Decimal('1.30')),
#  ('State of Palestine', 'Western Asia', None, None),
#  ('Sudan', 'Northern Africa', Decimal('1868000.00'), Decimal('28.26')),
#  ('Suriname', 'South America', Decimal('156000.00'), Decimal('1.01')),
#  ('Syrian Arab Republic', 'Western Asia', Decimal('183630.00'), Decimal('5.26')),
#  ('Tajikistan', 'Central Asia', Decimal('138790.00'), Decimal('3.70')),
#  ('Thailand', 'South-Eastern Asia', Decimal('510890.00'), Decimal('13.22')),
#  ('Timor-Leste', 'South-Eastern Asia', Decimal('14870.00'), Decimal('0.38')),
#  ('Togo', 'Western Africa', Decimal('54390.00'), Decimal('0.95')),
#  ('Tokelau', 'Polynesia', None, None),
#  ('Tonga', 'Polynesia', Decimal('720.00'), Decimal('9.98')),
#  ('Trinidad and Tobago', 'Caribbean', Decimal('5130.00'), Decimal('2.47')),
#  ('Tunisia', 'Northern Africa', Decimal('155360.00'), Decimal('2.35')),
#  ('Türkiye', 'Western Asia', None, None),
#  ('Turkmenistan', 'Central Asia', Decimal('469930.00'), Decimal('12.53')),
#  ('Turks and Caicos Islands', 'Caribbean', Decimal('950.00'), Decimal('0.46')),
#  ('Tuvalu', 'Polynesia', Decimal('30.00'), Decimal('0.42')),
#  ('Uganda', 'Eastern Africa', Decimal('200520.00'), Decimal('3.37')),
#  ('United Arab Emirates', 'Western Asia', Decimal('71020.00'), Decimal('2.04')),
#  ('United Republic of Tanzania', 'Eastern Africa', None, None),
#  ('United States of America', 'Northern America', None, None),
#  ('United States Virgin Islands', 'Caribbean', None, None),
#  ('Uruguay', 'South America', Decimal('175020.00'), Decimal('1.14')),
#  ('Uzbekistan', 'Central Asia', Decimal('440595.17'), Decimal('11.75')),
#  ('Vanuatu', 'Melanesia', Decimal('12190.00'), Decimal('2.30')),
#  ('Venezuela (Bolivarian Republic of)', 'South America', None, None),
#  ('Viet Nam', 'South-Eastern Asia', None, None),
#  ('Wallis and Futuna Islands', 'Polynesia', None, None),
#  ('Yemen', 'Western Asia', None, None),
#  ('Zambia', 'Eastern Africa', Decimal('743390.00'), Decimal('12.50')),
#  ('Zimbabwe', 'Eastern Africa', Decimal('386850.00'), Decimal('6.50'))]

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### 1. Calculate the total land area for each sub-region

# %%
# %%sql
#
# SELECT
#     Sub_region,
#     SUM(Land_area) AS Total_Land_Area
# FROM
#     Geographic_location
# GROUP BY
#     Sub_region

# %% [markdown]
# This gives us a table with a list of all the sub-regions and their total land areas calculated. In this case, we are not calculating a single value, but an entire table of values. Now we just join this table to the main one and reference the `Sub-region` as the key.

# %% [markdown]
# ### 2. Calculate country land area percentages for all the regions using a subquery in the JOIN clause

# %%
# %%sql
#
# SELECT
#     geoloc.Country_name,
#     geoloc.Land_area,
#     geoloc.Sub_region,
#     (geoloc.Land_area / Land_per_region.Total_Land_Area) * 100 AS Pct_Of_Region_Land
# FROM
#     Geographic_location AS geoloc
# JOIN
#     (
#     SELECT
#         Sub_region,
#         SUM(Land_area) AS Total_Land_Area
#     FROM
#         Geographic_location
#     GROUP BY
#         Sub_region)  AS Land_per_region
#     ON
#         geoloc.Sub_region = Land_per_region.sub_Region;

# %% [markdown]
# While this method may look a bit more complicated, it runs much faster than the previous method because it does not need to repeat calculations for each row. This is especially true for larger tables.

# %% [markdown]
# #
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/refs/heads/master/ALX_banners/ALX_Navy.png"  style="width:100px"  ;/>
# </div>
