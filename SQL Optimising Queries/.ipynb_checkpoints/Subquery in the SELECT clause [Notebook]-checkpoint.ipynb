# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img
#  src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/alx-courses/aice/assets/Content_page_banner_blue_dots.png"
#  alt="ALX Content Header"
#  class="full-width-image"
# />
# </div>

# %% [markdown]
# # Subquery in the SELECT clause

# %% [markdown]
# In this notebook, we will look at subqueries, which are powerful tools to enable more in-depth analysis in SQL. They are essentially intermediate results sets that we access with another query, so **a query inside another query**. We can use subqueries in various places in a query, and those subquery results also have various forms. Here, we look at the **use of a subquery in the `SELECT` clause.**

# %% [markdown]
# > ⚠️ This notebook will not run on Google Colab because it cannot connect to a local database. Please make sure that this notebook is running on the same local machine as your MySQL Workbench installation and MySQL `united_nations` database.

# %% [markdown]
# ## Learning objectives
#
# In this train, we will learn:
# - How to use **subqueries** instead of static values to make calculations dynamic.
# - How to turn a normal subquery into a **correlated subquery** to perform calculations based on specific criteria.

# %% [markdown]
# ## Overview
#
# Imagine we want to calculate the percentage of land area a specific country in a sub-region occupies, as a percentage of the total land area in that sub-region. That is a challenging question because we need to divide each country's land area with the sum of all countries in that sub-region.
# To do it, we can use a subquery. For example, let's just look at one sub-region for now, `Middle Africa`, and use the `Geographic_location` table to **find out the percentage of land each country has as a percentage of the total for 'Middle Africa'.**

# %% [markdown]
# ## Connecting to our MySQL database
#
# We will use our `Geographic_location` table in our `united_nations` database that we created in MySQL Workbench. We can apply the same queries we used in MySQL Workbench in this notebook if we connect to our MySQL server by running the cells below.

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook. 
# If you get an error here, make sure that mysql and pymysql are installed correctly. 

# %load_ext sql

# %%
# Establish a connection to the local database using the '%sql' magic command.
# Replace 'password' with our connection password and `db_name` with our database name. 
# If you get an error here, please make sure the database name or password is correct.

# %sql mysql+pymysql://root:Innovator1@localhost:3306/united_nations
# Out:
# 'Connected: root@united_nations'

# %%
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'

# %% [markdown]
# ## Exercise

# %% [markdown]
# ### 1. Calculate the total land area of the 'Middle Africa' sub-region
#
# Write a query that will find the `Land_area` sum for the `Middle Africa` sub-region. Call this column `total_land_area`.

# %%
# %%sql
#
# SELECT
# 	SUM(Land_area) AS total_land_area
# FROM
#     Geographic_location
# WHERE
# 	Sub_region = "Middle Africa";
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 1 rows affected.
# [(Decimal('3888270.00'),)]

# %% [markdown]
# ### 2. Calculate land area percentages for the Middle African countries using a static value
#
# Recall that, to find the percentage of land area each country in the `Middle Africa` sub-region occupies, we need to **divide each country’s land area with the `total_land_area`**, which we have calculated above. Copy and paste this land area value into a new query and calculate the percentages. Call this calculated column `pct_regional_land`.

# %%
# %%sql
#
# SELECT
#     Country_name,
#     Sub_region,
# 	ROUND((Land_area / 3888270.00) * 100, 2) AS pct_regional_land
# FROM
#     Geographic_location
# WHERE
# 	Sub_region = "Middle Africa";
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 9 rows affected.
# [('Angola', 'Middle Africa', Decimal('32.06')),
#  ('Cameroon', 'Middle Africa', Decimal('12.16')),
#  ('Central African Republic', 'Middle Africa', Decimal('16.02')),
#  ('Chad', 'Middle Africa', Decimal('32.38')),
#  ('Congo', 'Middle Africa', None),
#  ('Democratic Republic of the Congo', 'Middle Africa', None),
#  ('Equatorial Guinea', 'Middle Africa', Decimal('0.72')),
#  ('Gabon', 'Middle Africa', Decimal('6.63')),
#  ('Sao Tome and Principe', 'Middle Africa', Decimal('0.02'))]

# %% [markdown]
# ### 3. Calculate land area percentages for the Middle African countries using a subquery
#
# Instead of using the static value above, let's improve our query by using a subquery to achieve the same result.
#
# Hint: The subquery in this case will be the query we created to find the total land area in Exercise 1.

# %%
# %%sql
#
# SELECT
#     Country_name,
#     Sub_region,
# 	ROUND((Land_area / (SELECT
#                         	SUM(Land_area) AS total_land_area
#                         FROM
#                             Geographic_location
#                         WHERE
#                         	Sub_region = "Middle Africa"
#                        )
#           ) * 100, 2) AS pct_regional_land
# FROM
#     Geographic_location
# WHERE
# 	Sub_region = "Middle Africa";
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 9 rows affected.
# [('Angola', 'Middle Africa', Decimal('32.06')),
#  ('Cameroon', 'Middle Africa', Decimal('12.16')),
#  ('Central African Republic', 'Middle Africa', Decimal('16.02')),
#  ('Chad', 'Middle Africa', Decimal('32.38')),
#  ('Congo', 'Middle Africa', None),
#  ('Democratic Republic of the Congo', 'Middle Africa', None),
#  ('Equatorial Guinea', 'Middle Africa', Decimal('0.72')),
#  ('Gabon', 'Middle Africa', Decimal('6.63')),
#  ('Sao Tome and Principe', 'Middle Africa', Decimal('0.02'))]

# %% [markdown]
# ### Correlated subqueries
#
# With a normal nested subquery (uncorrelated), **it runs first and executes once**, returning value(s) to be used by the outer query. This is what we have above where our subquery calculates the land area sum for the `Middle Africa` sub-region, and this is the value that is returned to the outer query to calculate land area percentages.
#
# If we want to calculate the land area percentages for all the regions, we would need to manually edit the search string in the `WHERE` clause, which is not very practical.
#
# Instead, we can use a **correlated subquery**. This is a type of subquery that is **executed once for every row processed by the outer query**. It is often used when you need to perform a calculation based on values in the current row of the outer query. In our case, we want the subquery to calculate the land area sum based on the sub-region value of the current row being processed by the outer query.
#
# Below is a general syntax template where a correlated subquery has been used:

# %% [markdown]
# ```
# SELECT
#     outer_column1,
#     outer_column2
# FROM
#     outer_table AS outer_alias
# WHERE
#     expression operator (
#                         SELECT
#                             aggregate_function(inner_column)
#                         FROM
#                             inner_table AS inner_alias
#                         WHERE
#                             inner_column = outer_alias.outer_column2
#                         )
# ;
# ```

# %% [markdown]
# ### 4. Calculate country land area percentages for all the regions using a correlated subquery
#
# Transform the subquery in Exercise 2 into a correlated subquery that will calculate land area percentages for all the regions.
#
# Hint: Use the general syntax above to help you figure out how to achieve this.

# %%
# %%sql
#
# SELECT
#     Country_name,
#     Sub_region,
# 	ROUND((Land_area / (SELECT
#                         	SUM(Land_area) AS total_land_area
#                         FROM
#                             Geographic_location
#                         WHERE
#                         	Sub_region = g.Sub_region
#                        )
#           ) * 100, 2) AS pct_regional_land
# FROM
#     Geographic_location g;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 182 rows affected.
# [('Afghanistan', 'Southern Asia', Decimal('13.67')),
#  ('Algeria', 'Northern Africa', Decimal('36.03')),
#  ('American Samoa', 'Polynesia', Decimal('2.77')),
#  ('Angola', 'Middle Africa', Decimal('32.06')),
#  ('Anguilla', 'Caribbean', None),
#  ('Antigua and Barbuda', 'Caribbean', Decimal('0.21')),
#  ('Argentina', 'South America', Decimal('17.77')),
#  ('Armenia', 'Western Asia', Decimal('0.82')),
#  ('Aruba', 'Caribbean', Decimal('0.09')),
#  ('Australia', 'Australia and New Zealand', Decimal('96.69')),
#  ('Azerbaijan', 'Western Asia', Decimal('2.37')),
#  ('Bahamas', 'Caribbean', None),
#  ('Bahrain', 'Western Asia', Decimal('0.02')),
#  ('Bangladesh', 'Southern Asia', Decimal('2.73')),
#  ('Barbados', 'Caribbean', Decimal('0.21')),
#  ('Belize', 'Central America', Decimal('0.93')),
#  ('Benin', 'Western Africa', Decimal('1.97')),
#  ('Bermuda', 'Northern America', Decimal('0.00')),
#  ('Bhutan', 'Southern Asia', Decimal('0.80')),
#  ('Bolivia (Plurinational State of)', 'South America', None),
#  ('Botswana', 'Southern Africa', Decimal('21.38')),
#  ('Brazil', 'South America', Decimal('54.27')),
#  ('British Virgin Islands', 'Caribbean', Decimal('0.07')),
#  ('Brunei Darussalam', 'South-Eastern Asia', Decimal('0.14')),
#  ('Burkina Faso', 'Western Africa', Decimal('4.77')),
#  ('Burundi', 'Eastern Africa', Decimal('0.43')),
#  ('Cabo Verde', 'Western Africa', Decimal('0.07')),
#  ('Cambodia', 'South-Eastern Asia', Decimal('4.57')),
#  ('Cameroon', 'Middle Africa', Decimal('12.16')),
#  ('Canada', 'Northern America', Decimal('95.62')),
#  ('Cayman Islands', 'Caribbean', Decimal('0.12')),
#  ('Central African Republic', 'Middle Africa', Decimal('16.02')),
#  ('Chad', 'Middle Africa', Decimal('32.38')),
#  ('Chile', 'South America', Decimal('4.83')),
#  ('China', 'Eastern Asia', Decimal('83.06')),
#  ('Colombia', 'South America', Decimal('7.20')),
#  ('Comoros', 'Eastern Africa', Decimal('0.03')),
#  ('Congo', 'Middle Africa', None),
#  ('Cook Islands', 'Polynesia', None),
#  ('Costa Rica', 'Central America', Decimal('2.08')),
#  ("Côte d'Ivoire", 'Western Africa', None),
#  ('Cuba', 'Caribbean', Decimal('49.92')),
#  ('Curaçao', 'Caribbean', None),
#  ('Cyprus', 'Western Asia', Decimal('0.26')),
#  ("Democratic People's Republic of Korea", 'Eastern Asia', None),
#  ('Democratic Republic of the Congo', 'Middle Africa', None),
#  ('Djibouti', 'Eastern Africa', Decimal('0.39')),
#  ('Dominica', 'Caribbean', Decimal('0.36')),
#  ('Dominican Republic', 'Caribbean', Decimal('23.21')),
#  ('Ecuador', 'South America', Decimal('1.61')),
#  ('Egypt', 'Northern Africa', None),
#  ('El Salvador', 'Central America', Decimal('0.84')),
#  ('Equatorial Guinea', 'Middle Africa', Decimal('0.72')),
#  ('Eritrea', 'Eastern Africa', Decimal('2.04')),
#  ('Eswatini', 'Southern Africa', Decimal('0.65')),
#  ('Ethiopia', 'Eastern Africa', Decimal('18.97')),
#  ('Falkland Islands (Malvinas)', 'South America', None),
#  ('Fiji', 'Melanesia', Decimal('3.45')),
#  ('French Guiana', 'South America', None),
#  ('French Polynesia', 'Polynesia', Decimal('48.09')),
#  ('Gabon', 'Middle Africa', Decimal('6.63')),
#  ('Gambia', 'Western Africa', None),
#  ('Georgia', 'Western Asia', Decimal('1.99')),
#  ('Ghana', 'Western Africa', Decimal('3.97')),
#  ('Greenland', 'Northern America', Decimal('4.38')),
#  ('Grenada', 'Caribbean', Decimal('0.16')),
#  ('Guadeloupe', 'Caribbean', None),
#  ('Guam', 'Micronesia', Decimal('21.86')),
#  ('Guatemala', 'Central America', Decimal('4.37')),
#  ('Guinea', 'Western Africa', Decimal('4.28')),
#  ('Guinea-Bissau', 'Western Africa', Decimal('0.49')),
#  ('Guyana', 'South America', Decimal('1.28')),
#  ('Haiti', 'Caribbean', Decimal('13.24')),
#  ('Honduras', 'Central America', Decimal('4.56')),
#  ('India', 'Southern Asia', Decimal('62.33')),
#  ('Indonesia', 'South-Eastern Asia', Decimal('48.57')),
#  ('Iran (Islamic Republic of)', 'Southern Asia', None),
#  ('Iraq', 'Western Asia', Decimal('12.44')),
#  ('Israel', 'Western Asia', Decimal('0.62')),
#  ('Jamaica', 'Caribbean', Decimal('5.20')),
#  ('Japan', 'Eastern Asia', Decimal('3.21')),
#  ('Jordan', 'Western Asia', Decimal('2.55')),
#  ('Kazakhstan', 'Central Asia', Decimal('72.01')),
#  ('Kenya', 'Eastern Africa', Decimal('9.57')),
#  ('Kiribati', 'Micronesia', Decimal('32.79')),
#  ('Kuwait', 'Western Asia', Decimal('0.51')),
#  ('Kyrgyzstan', 'Central Asia', None),
#  ("Lao People's Democratic Republic", 'South-Eastern Asia', None),
#  ('Lebanon', 'Western Asia', Decimal('0.29')),
#  ('Lesotho', 'Southern Africa', Decimal('1.15')),
#  ('Liberia', 'Western Africa', Decimal('1.68')),
#  ('Libya', 'Northern Africa', Decimal('26.62')),
#  ('Madagascar', 'Eastern Africa', Decimal('9.78')),
#  ('Malawi', 'Eastern Africa', Decimal('1.58')),
#  ('Malaysia', 'South-Eastern Asia', Decimal('8.50')),
#  ('Maldives', 'Southern Asia', Decimal('0.01')),
#  ('Mali', 'Western Africa', Decimal('21.27')),
#  ('Marshall Islands', 'Micronesia', Decimal('7.29')),
#  ('Martinique', 'Caribbean', None),
#  ('Mauritania', 'Western Africa', Decimal('17.97')),
#  ('Mauritius', 'Eastern Africa', Decimal('0.03')),
#  ('Mayotte', 'Eastern Africa', None),
#  ('Mexico', 'Central America', Decimal('79.28')),
#  ('Micronesia (Federated States of)', 'Micronesia', None),
#  ('Mongolia', 'Eastern Asia', Decimal('13.72')),
#  ('Montserrat', 'Caribbean', None),
#  ('Morocco', 'Northern Africa', Decimal('6.75')),
#  ('Mozambique', 'Eastern Africa', Decimal('13.22')),
#  ('Myanmar', 'South-Eastern Asia', Decimal('16.89')),
#  ('Namibia', 'Southern Africa', Decimal('31.06')),
#  ('Nauru', 'Micronesia', Decimal('0.81')),
#  ('Nepal', 'Southern Asia', Decimal('3.01')),
#  ('New Caledonia', 'Melanesia', Decimal('3.45')),
#  ('New Zealand', 'Australia and New Zealand', Decimal('3.31')),
#  ('Nicaragua', 'Central America', Decimal('4.91')),
#  ('Niger', 'Western Africa', Decimal('22.09')),
#  ('Nigeria', 'Western Africa', Decimal('15.88')),
#  ('Niue', 'Polynesia', None),
#  ('Northern Mariana Islands', 'Micronesia', Decimal('18.62')),
#  ('Oman', 'Western Asia', Decimal('8.87')),
#  ('Pakistan', 'Southern Asia', Decimal('16.16')),
#  ('Palau', 'Micronesia', Decimal('18.62')),
#  ('Panama', 'Central America', Decimal('3.02')),
#  ('Papua New Guinea', 'Melanesia', Decimal('85.51')),
#  ('Paraguay', 'South America', Decimal('2.58')),
#  ('Peru', 'South America', Decimal('8.31')),
#  ('Philippines', 'South-Eastern Asia', Decimal('7.71')),
#  ('Puerto Rico', 'Caribbean', Decimal('4.26')),
#  ('Qatar', 'Western Asia', Decimal('0.33')),
#  ('Republic of Korea', 'Eastern Asia', None),
#  ('Réunion', 'Eastern Africa', None),
#  ('Rwanda', 'Eastern Africa', Decimal('0.41')),
#  ('Saint Barthélemy', 'Caribbean', None),
#  ('Saint Helena', 'Western Africa', None),
#  ('Saint Kitts and Nevis', 'Caribbean', None),
#  ('Saint Lucia', 'Caribbean', None),
#  ('Saint Martin (French Part)', 'Caribbean', None),
#  ('Saint Pierre and Miquelon', 'Northern America', None),
#  ('Saint Vincent and the Grenadines', 'Caribbean', None),
#  ('Samoa', 'Polynesia', Decimal('38.75')),
#  ('Sao Tome and Principe', 'Middle Africa', Decimal('0.02')),
#  ('Saudi Arabia', 'Western Asia', Decimal('61.62')),
#  ('Senegal', 'Western Africa', Decimal('3.36')),
#  ('Seychelles', 'Eastern Africa', Decimal('0.01')),
#  ('Sierra Leone', 'Western Africa', Decimal('1.26')),
#  ('Singapore', 'South-Eastern Asia', Decimal('0.02')),
#  ('Sint Maarten (Dutch part)', 'Caribbean', Decimal('0.02')),
#  ('Solomon Islands', 'Melanesia', Decimal('5.29')),
#  ('Somalia', 'Eastern Africa', Decimal('10.55')),
#  ('South Africa', 'Southern Africa', Decimal('45.77')),
#  ('South Sudan', 'Eastern Africa', Decimal('10.62')),
#  ('Sri Lanka', 'Southern Asia', Decimal('1.30')),
#  ('State of Palestine', 'Western Asia', None),
#  ('Sudan', 'Northern Africa', Decimal('28.26')),
#  ('Suriname', 'South America', Decimal('1.01')),
#  ('Syrian Arab Republic', 'Western Asia', Decimal('5.26')),
#  ('Tajikistan', 'Central Asia', Decimal('3.70')),
#  ('Thailand', 'South-Eastern Asia', Decimal('13.22')),
#  ('Timor-Leste', 'South-Eastern Asia', Decimal('0.38')),
#  ('Togo', 'Western Africa', Decimal('0.95')),
#  ('Tokelau', 'Polynesia', None),
#  ('Tonga', 'Polynesia', Decimal('9.98')),
#  ('Trinidad and Tobago', 'Caribbean', Decimal('2.47')),
#  ('Tunisia', 'Northern Africa', Decimal('2.35')),
#  ('Türkiye', 'Western Asia', None),
#  ('Turkmenistan', 'Central Asia', Decimal('12.53')),
#  ('Turks and Caicos Islands', 'Caribbean', Decimal('0.46')),
#  ('Tuvalu', 'Polynesia', Decimal('0.42')),
#  ('Uganda', 'Eastern Africa', Decimal('3.37')),
#  ('United Arab Emirates', 'Western Asia', Decimal('2.04')),
#  ('United Republic of Tanzania', 'Eastern Africa', None),
#  ('United States of America', 'Northern America', None),
#  ('United States Virgin Islands', 'Caribbean', None),
#  ('Uruguay', 'South America', Decimal('1.14')),
#  ('Uzbekistan', 'Central Asia', Decimal('11.75')),
#  ('Vanuatu', 'Melanesia', Decimal('2.30')),
#  ('Venezuela (Bolivarian Republic of)', 'South America', None),
#  ('Viet Nam', 'South-Eastern Asia', None),
#  ('Wallis and Futuna Islands', 'Polynesia', None),
#  ('Yemen', 'Western Asia', None),
#  ('Zambia', 'Eastern Africa', Decimal('12.50')),
#  ('Zimbabwe', 'Eastern Africa', Decimal('6.50'))]

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### 1. Calculate the total land area of the 'Middle Africa' sub-region

# %%
# %%sql
#
# SELECT
#     SUM(Land_area) as total_land_area
# FROM
#     Geographic_location
# WHERE
#     Sub_region = 'Middle Africa';

# %% [markdown]
# This query will return a single value which is the sum of all of the `Land_area` for the `Middle Africa` sub-region.

# %% [markdown]
# ### 2. Calculate land area percentages for the Middle African countries using a static value
#
# To calculate the percentages, we select the country names and the land area for each country, which we then divide by the total area for Middle Africa multiplied by 100 (to get the percentage), and then round the result off.
#
# **Note:** In the above query, we calculated a `total_land_area` of **"3888270.00"** which we'll use in the query below to calculate percentages for each country.

# %%
# %%sql
#
# SELECT
#     Country_name,
#     ROUND(Land_area/3888270.00*100) AS  pct_regional_land
# FROM
#     Geographic_location
# WHERE
#     Sub_region = 'Middle Africa';

# %% [markdown]
# ### 3. Calculate land area percentages for the Middle African countries using a subquery
#
# We replace the static value above with the query that generated that result (the query in Exercise 1).

# %%
# %%sql
#
# SELECT
#     Country_name,
#     ROUND(land_area / (
#                         SELECT
#                             SUM(Land_area)
#                         FROM
#                             Geographic_location
#                         WHERE
#                             Sub_region = 'Middle Africa') * 100, 2) as Pct_regional_land
# FROM
#     Geographic_location
# WHERE
#     Sub_region = 'Middle Africa';

# %% [markdown]
# When we execute this, the inner query runs first and calculates the sum value, then “passes” that to the outer query to get the percentages. A subquery that passes a single value to the outer query is known as a **scalar subquery.**
#
# The benefit of using the subquery instead of the actual value is that if we want to do the same for another sub-region, we can just change the search string, “Middle Africa”, for example, to "Polynesia". It will process the same calculation using the Polynesian data. These types of calculations are known as **dynamic**. By changing some of the filters, we automatically calculate the corresponding sum.

# %% [markdown]
# ### 4. Calculate land area percentages for all the regions using a correlated subquery
#
# We replace **“Middle Africa”** with a reference to the field that will change for each row, that is, the `Sub_region`. In order for this to work, we have to give the table in our main query an alias, **`g`**, so that when we refer to it in the subquery, SQL knows we are talking about the outer query’s table.

# %%
# %%sql
#
# SELECT
#     Country_name,
#     ROUND(Land_area / (
#                         SELECT
#                             SUM(Land_area)
#                         FROM
#                             Geographic_location
#                         WHERE
#                             Sub_region = g.Sub_region) * 100, 2) as Pct_regional_land
# FROM
#     Geographic_location AS g;

# %% [markdown]
# As SQL looks at the first row in **`g`**, the sub-region of the first row is **`g.sub-Region`**.
#
# So for the first row, the sub-region will be `Central and Southern Asia`. The inner query will then execute, filtering out the Central and Southern Asia data, and calculate the sum of the land area in Central and Southern Asia. The main query then uses that value to calculate the percentage. SQL then moves to the second row. This time, the sub-region is `Northern Africa and Western Asia`, which the subquery uses again, and passes back to the main query, and so on.

# %% [markdown]
# The downside of using correlated subqueries is that they can be quite inefficient. This is because the subquery may be evaluated once for each row processed by the outer query. For example, once we have calculated the total area for Middle Africa, the same calculation will be repeated for another row.

# %% [markdown]
# #
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/refs/heads/master/ALX_banners/ALX_Navy.png"  style="width:100px"  ;/>
# </div>
