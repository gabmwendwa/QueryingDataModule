# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img
#  src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/alx-courses/aice/assets/Content_page_banner_blue_dots.png"
#  alt="ALX Content Header"
#  class="full-width-image"
# />
# </div>

# %% [markdown]
# # Subquery in  WHERE

# %% [markdown]
# In this notebook, we delve deeper into subqueries, specifically subqueries within a WHERE clause. One of the powerful aspects of subqueries is their ability to compare individual rows with aggregated data. This concept will be explored here.

# %% [markdown]
# > ⚠️ This notebook will not run on Google Colab because it cannot connect to a local database. Please make sure that this notebook is running on the same local machine as your MySQL Workbench installation and MySQL `united_nations` database.

# %% [markdown]
# ## Learning objectives
#
# In this train, we will learn:
# - How to use the WHERE clause in subqueries.
# - How to join tables.

# %% [markdown]
# ## Connecting to our MySQL database
#
# Using our `Access_to_Basic_Services` table in our `united_nations` database we created in MySQL Workbench, we want to answer some questions about our dataset. We can apply the same queries we used in MySQL Workbench in this notebook if we connect to our MySQL server by running the cells below.
#
# Note that before this tutorial, we will already have worked through the lessons where the `united_nations.Basic_Services` table, `united_nations.Economic_Indicators` table, and `united_nations.Geographic_Locations` table were created.

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook. 
# If you get an error here, make sure that mysql and pymysql are installed correctly. 

# %load_ext sql

# %%
# Establish a connection to the local database using the '%sql' magic command.
# Replace 'password' with our connection password and `db_name` with our database name. 
# If you get an error here, please make sure the database name or password is correct.

# %sql mysql+pymysql://root:Innovator1@localhost:3306/united_nations
# Out:
# 'Connected: root@united_nations'

# %%
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'

# %% [markdown]
# To make a query, we add the `%%sql` command to the start of a cell, create one open line then the query like below, and run the cell.

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     Access_to_Basic_Services
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 5 rows affected.
# [('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2015, Decimal('94.67'), Decimal('98.00'), Decimal('17.542806'), Decimal('184.39'), Decimal('2699700.00'), Decimal('4.93')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2016, Decimal('94.67'), Decimal('98.00'), Decimal('17.794055'), Decimal('137.28'), Decimal('2699700.00'), Decimal('4.96')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2017, Decimal('95.00'), Decimal('98.00'), Decimal('18.037776'), Decimal('166.81'), Decimal('2699700.00'), Decimal('4.90')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2018, Decimal('95.00'), Decimal('98.00'), Decimal('18.276452'), Decimal('179.34'), Decimal('2699700.00'), Decimal('4.85')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2019, Decimal('95.00'), Decimal('98.00'), Decimal('18.513673'), Decimal('181.67'), Decimal('2699700.00'), Decimal('4.80'))]

# %% [markdown]
# ## Exercise

# %% [markdown]
# We want to answer the following question:
#
# For the year 2020, which countries have a GDP above the global average, but still have less than 90% of their population with access to managed drinking water services?
#
# This question will shed light on nations that, despite having a robust economy, may still be facing challenges in providing basic amenities like water.

# %% [markdown]
# ### Task 1
#
# Start by constructing a query that displays the average GDP of a country during the year 2020.

# %%
# %%sql
#
# SELECT
#     AVG(Est_gdp_in_billions)
# FROM
#     united_nations.Economic_Indicators
# WHERE
# 	Time_period = 2020;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 1 rows affected.
# [(Decimal('301.176825'),)]

# %% [markdown]
# ### Task 2

# %% [markdown]
# In order to answer our question, we need to pull data from both the Economic_Indicators and the Basic_Services tables; therefore, we need to join them together. Using `Country_name` and  `Time_period`, join the Basic_Services table to the Economic_Indicators table.

# %%
# %%sql
#
# SELECT
# 	b.Country_name,
#     b.Time_period,
#     e.Est_gdp_in_billions,
#     b.Pct_managed_drinking_water_services
# FROM
# 	united_nations.basic_services b
# INNER JOIN
# 	united_nations.economic_indicators e
#     ON
# 		b.Country_name = e.Country_name
# 	AND
# 		b.Time_period = e.Time_period;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 1048 rows affected.
# [('Afghanistan', 2015, Decimal('20.00'), Decimal('67.00')),
#  ('Afghanistan', 2016, Decimal('18.02'), Decimal('69.67')),
#  ('Afghanistan', 2017, Decimal('18.90'), Decimal('72.33')),
#  ('Afghanistan', 2018, Decimal('18.42'), Decimal('75.33')),
#  ('Afghanistan', 2019, Decimal('18.90'), Decimal('78.00')),
#  ('Afghanistan', 2020, Decimal('20.14'), Decimal('80.33')),
#  ('Algeria', 2015, Decimal('165.98'), Decimal('92.00')),
#  ('Algeria', 2016, Decimal('160.03'), Decimal('93.00')),
#  ('Algeria', 2017, Decimal('170.10'), Decimal('93.00')),
#  ('Algeria', 2018, Decimal('174.91'), Decimal('93.00')),
#  ('Algeria', 2019, Decimal('171.77'), Decimal('93.33')),
#  ('Algeria', 2020, Decimal('145.01'), Decimal('93.33')),
#  ('American Samoa', 2015, Decimal('0.67'), Decimal('100.00')),
#  ('American Samoa', 2016, Decimal('0.67'), Decimal('100.00')),
#  ('American Samoa', 2017, Decimal('0.61'), Decimal('100.00')),
#  ('American Samoa', 2018, Decimal('0.64'), Decimal('100.00')),
#  ('American Samoa', 2019, Decimal('0.65'), Decimal('100.00')),
#  ('American Samoa', 2020, Decimal('0.72'), Decimal('100.00')),
#  ('Angola', 2015, Decimal('87.22'), Decimal('50.33')),
#  ('Angola', 2016, Decimal('49.84'), Decimal('51.00')),
#  ('Angola', 2017, Decimal('68.97'), Decimal('51.33')),
#  ('Angola', 2018, Decimal('77.79'), Decimal('52.33')),
#  ('Angola', 2019, Decimal('69.31'), Decimal('52.33')),
#  ('Angola', 2020, Decimal('53.62'), Decimal('52.33')),
#  ('Anguilla', 2015, None, Decimal('97.00')),
#  ('Anguilla', 2016, None, Decimal('97.00')),
#  ('Anguilla', 2017, None, Decimal('97.00')),
#  ('Antigua and Barbuda', 2015, Decimal('1.34'), Decimal('97.00')),
#  ('Antigua and Barbuda', 2016, Decimal('1.44'), Decimal('97.00')),
#  ('Antigua and Barbuda', 2017, Decimal('1.47'), Decimal('97.00')),
#  ('Argentina', 2015, Decimal('594.75'), Decimal('97.33')),
#  ('Argentina', 2016, Decimal('557.53'), Decimal('97.33')),
#  ('Argentina', 2017, Decimal('643.63'), Decimal('100.00')),
#  ('Argentina', 2018, Decimal('524.82'), Decimal('100.00')),
#  ('Argentina', 2019, Decimal('447.75'), Decimal('100.00')),
#  ('Argentina', 2020, Decimal('385.54'), Decimal('100.00')),
#  ('Armenia', 2015, Decimal('10.55'), Decimal('99.67')),
#  ('Armenia', 2016, Decimal('10.55'), Decimal('99.67')),
#  ('Armenia', 2017, Decimal('11.53'), Decimal('100.00')),
#  ('Armenia', 2018, Decimal('12.46'), Decimal('100.00')),
#  ('Armenia', 2019, Decimal('13.62'), Decimal('100.00')),
#  ('Armenia', 2020, Decimal('12.64'), Decimal('100.00')),
#  ('Aruba', 2015, Decimal('2.96'), Decimal('98.00')),
#  ('Aruba', 2016, Decimal('2.98'), Decimal('98.00')),
#  ('Australia', 2015, Decimal('1350.62'), Decimal('100.00')),
#  ('Australia', 2016, Decimal('1206.54'), Decimal('100.00')),
#  ('Australia', 2017, Decimal('1326.52'), Decimal('100.00')),
#  ('Australia', 2018, Decimal('1428.29'), Decimal('100.00')),
#  ('Australia', 2019, Decimal('1392.23'), Decimal('100.00')),
#  ('Australia', 2020, Decimal('1326.90'), Decimal('100.00')),
#  ('Azerbaijan', 2015, Decimal('53.07'), Decimal('91.67')),
#  ('Azerbaijan', 2016, Decimal('37.87'), Decimal('92.33')),
#  ('Azerbaijan', 2017, Decimal('40.87'), Decimal('93.67')),
#  ('Azerbaijan', 2018, Decimal('47.11'), Decimal('94.33')),
#  ('Azerbaijan', 2019, Decimal('48.17'), Decimal('95.00')),
#  ('Azerbaijan', 2020, Decimal('42.69'), Decimal('95.67')),
#  ('Bahamas', 2015, None, Decimal('99.00')),
#  ('Bahamas', 2016, None, Decimal('99.00')),
#  ('Bahamas', 2017, None, Decimal('99.00')),
#  ('Bahamas', 2018, None, Decimal('99.00')),
#  ('Bahamas', 2019, None, Decimal('99.00')),
#  ('Bahrain', 2015, Decimal('31.05'), Decimal('100.00')),
#  ('Bahrain', 2016, Decimal('32.23'), Decimal('100.00')),
#  ('Bahrain', 2017, Decimal('35.47'), Decimal('100.00')),
#  ('Bahrain', 2018, Decimal('37.80'), Decimal('100.00')),
#  ('Bahrain', 2019, Decimal('38.65'), Decimal('100.00')),
#  ('Bahrain', 2020, Decimal('34.72'), Decimal('100.00')),
#  ('Bangladesh', 2015, Decimal('195.08'), Decimal('97.33')),
#  ('Bangladesh', 2016, Decimal('265.24'), Decimal('97.33')),
#  ('Bangladesh', 2017, Decimal('293.75'), Decimal('97.33')),
#  ('Bangladesh', 2018, Decimal('321.38'), Decimal('97.33')),
#  ('Bangladesh', 2019, Decimal('351.24'), Decimal('97.67')),
#  ('Bangladesh', 2020, Decimal('373.90'), Decimal('97.67')),
#  ('Barbados', 2015, Decimal('4.72'), Decimal('98.00')),
#  ('Barbados', 2016, Decimal('4.83'), Decimal('98.00')),
#  ('Barbados', 2017, Decimal('4.98'), Decimal('98.00')),
#  ('Barbados', 2018, Decimal('5.10'), Decimal('99.00')),
#  ('Barbados', 2019, Decimal('5.32'), Decimal('99.00')),
#  ('Barbados', 2020, Decimal('4.67'), Decimal('99.00')),
#  ('Belize', 2015, Decimal('2.21'), Decimal('97.33')),
#  ('Belize', 2016, Decimal('2.26'), Decimal('97.67')),
#  ('Belize', 2017, Decimal('2.29'), Decimal('98.00')),
#  ('Belize', 2018, Decimal('2.31'), Decimal('98.33')),
#  ('Belize', 2019, Decimal('2.42'), Decimal('98.33')),
#  ('Belize', 2020, Decimal('2.08'), Decimal('98.33')),
#  ('Benin', 2015, Decimal('11.39'), Decimal('65.33')),
#  ('Benin', 2016, Decimal('11.82'), Decimal('65.33')),
#  ('Benin', 2017, Decimal('12.70'), Decimal('65.33')),
#  ('Benin', 2018, Decimal('14.26'), Decimal('65.67')),
#  ('Benin', 2019, Decimal('14.39'), Decimal('65.33')),
#  ('Benin', 2020, Decimal('15.65'), Decimal('65.33')),
#  ('Bermuda', 2015, Decimal('6.65'), Decimal('100.00')),
#  ('Bermuda', 2016, Decimal('6.90'), Decimal('100.00')),
#  ('Bermuda', 2017, Decimal('7.14'), Decimal('100.00')),
#  ('Bermuda', 2018, Decimal('7.23'), Decimal('100.00')),
#  ('Bermuda', 2019, Decimal('7.42'), Decimal('100.00')),
#  ('Bermuda', 2020, Decimal('6.89'), Decimal('100.00')),
#  ('Bhutan', 2015, Decimal('2.00'), Decimal('96.33')),
#  ('Bhutan', 2016, Decimal('2.16'), Decimal('97.00')),
#  ('Bhutan', 2017, Decimal('2.45'), Decimal('97.33')),
#  ('Bhutan', 2018, Decimal('2.45'), Decimal('97.33')),
#  ('Bhutan', 2019, Decimal('2.54'), Decimal('97.33')),
#  ('Bhutan', 2020, Decimal('2.33'), Decimal('97.33')),
#  ('Bolivia (Plurinational State of)', 2015, None, Decimal('87.33')),
#  ('Bolivia (Plurinational State of)', 2016, None, Decimal('88.00')),
#  ('Bolivia (Plurinational State of)', 2017, None, Decimal('89.00')),
#  ('Bolivia (Plurinational State of)', 2018, None, Decimal('89.67')),
#  ('Bolivia (Plurinational State of)', 2019, None, Decimal('90.33')),
#  ('Bolivia (Plurinational State of)', 2020, None, Decimal('90.67')),
#  ('Botswana', 2015, Decimal('13.53'), Decimal('85.67')),
#  ('Botswana', 2016, Decimal('15.08'), Decimal('86.67')),
#  ('Botswana', 2017, Decimal('16.11'), Decimal('87.67')),
#  ('Botswana', 2018, Decimal('17.03'), Decimal('88.33')),
#  ('Botswana', 2019, Decimal('16.70'), Decimal('89.67')),
#  ('Botswana', 2020, Decimal('14.93'), Decimal('89.67')),
#  ('Brazil', 2015, Decimal('1802.21'), Decimal('95.33')),
#  ('Brazil', 2016, Decimal('1795.70'), Decimal('95.33')),
#  ('Brazil', 2017, Decimal('2063.51'), Decimal('96.33')),
#  ('Brazil', 2018, Decimal('1916.95'), Decimal('97.00')),
#  ('Brazil', 2019, Decimal('1873.27'), Decimal('97.33')),
#  ('Brazil', 2020, Decimal('1448.56'), Decimal('98.33')),
#  ('British Virgin Islands', 2015, None, Decimal('100.00')),
#  ('British Virgin Islands', 2016, None, Decimal('100.00')),
#  ('British Virgin Islands', 2017, None, Decimal('100.00')),
#  ('British Virgin Islands', 2018, None, Decimal('100.00')),
#  ('British Virgin Islands', 2019, None, Decimal('100.00')),
#  ('British Virgin Islands', 2020, None, Decimal('100.00')),
#  ('Brunei Darussalam', 2015, Decimal('12.93'), Decimal('99.67')),
#  ('Brunei Darussalam', 2016, Decimal('11.40'), Decimal('100.00')),
#  ('Brunei Darussalam', 2017, Decimal('12.13'), Decimal('100.00')),
#  ('Brunei Darussalam', 2018, Decimal('13.57'), Decimal('100.00')),
#  ('Brunei Darussalam', 2019, Decimal('13.47'), Decimal('100.00')),
#  ('Brunei Darussalam', 2020, Decimal('12.01'), Decimal('100.00')),
#  ('Burkina Faso', 2015, Decimal('11.83'), Decimal('56.33')),
#  ('Burkina Faso', 2016, Decimal('12.83'), Decimal('56.00')),
#  ('Burkina Faso', 2017, Decimal('14.11'), Decimal('55.00')),
#  ('Burkina Faso', 2018, Decimal('15.89'), Decimal('54.33')),
#  ('Burkina Faso', 2019, Decimal('16.18'), Decimal('54.00')),
#  ('Burkina Faso', 2020, Decimal('17.93'), Decimal('53.33')),
#  ('Burundi', 2015, Decimal('3.10'), Decimal('68.33')),
#  ('Burundi', 2016, Decimal('2.64'), Decimal('68.33')),
#  ('Burundi', 2017, Decimal('2.71'), Decimal('69.33')),
#  ('Burundi', 2018, Decimal('2.66'), Decimal('69.33')),
#  ('Burundi', 2019, Decimal('2.58'), Decimal('70.33')),
#  ('Burundi', 2020, Decimal('2.65'), Decimal('70.33')),
#  ('Cabo Verde', 2015, Decimal('1.60'), Decimal('83.33')),
#  ('Cabo Verde', 2016, Decimal('1.66'), Decimal('84.33')),
#  ('Cabo Verde', 2017, Decimal('1.77'), Decimal('85.33')),
#  ('Cabo Verde', 2018, Decimal('1.97'), Decimal('86.00')),
#  ('Cabo Verde', 2019, Decimal('1.98'), Decimal('86.67')),
#  ('Cabo Verde', 2020, Decimal('1.70'), Decimal('87.33')),
#  ('Cambodia', 2015, Decimal('18.05'), Decimal('73.33')),
#  ('Cambodia', 2016, Decimal('20.02'), Decimal('73.67')),
#  ('Cambodia', 2017, Decimal('22.18'), Decimal('74.33')),
#  ('Cambodia', 2018, Decimal('24.57'), Decimal('74.67')),
#  ('Cambodia', 2019, Decimal('27.09'), Decimal('75.33')),
#  ('Cambodia', 2020, Decimal('25.87'), Decimal('75.33')),
#  ('Cameroon', 2015, Decimal('32.21'), Decimal('62.67')),
#  ('Cameroon', 2016, Decimal('33.81'), Decimal('62.67')),
#  ('Cameroon', 2017, Decimal('36.10'), Decimal('63.33')),
#  ('Cameroon', 2018, Decimal('39.97'), Decimal('63.33')),
#  ('Cameroon', 2019, Decimal('39.67'), Decimal('63.33')),
#  ('Cameroon', 2020, Decimal('40.77'), Decimal('64.00')),
#  ('Canada', 2015, Decimal('1556.51'), Decimal('99.00')),
#  ('Canada', 2016, Decimal('1527.99'), Decimal('99.00')),
#  ('Canada', 2017, Decimal('1649.27'), Decimal('99.00')),
#  ('Canada', 2018, Decimal('1725.33'), Decimal('99.00')),
#  ('Canada', 2019, Decimal('1742.02'), Decimal('99.00')),
#  ('Canada', 2020, Decimal('1645.42'), Decimal('99.00')),
#  ('Cayman Islands', 2015, Decimal('4.71'), Decimal('96.00')),
#  ('Cayman Islands', 2016, Decimal('4.91'), Decimal('96.00')),
#  ('Central African Republic', 2015, Decimal('1.70'), Decimal('44.00')),
#  ('Central African Republic', 2016, Decimal('1.83'), Decimal('42.67')),
#  ('Central African Republic', 2017, Decimal('2.07'), Decimal('41.33')),
#  ('Central African Republic', 2018, Decimal('2.22'), Decimal('40.67')),
#  ('Central African Republic', 2019, Decimal('2.22'), Decimal('39.33')),
#  ('Central African Republic', 2020, Decimal('2.33'), Decimal('38.33')),
#  ('Chad', 2015, Decimal('10.95'), Decimal('51.67')),
#  ('Chad', 2016, Decimal('10.10'), Decimal('52.00')),
#  ('Chad', 2017, Decimal('10.00'), Decimal('52.00')),
#  ('Chad', 2018, Decimal('11.24'), Decimal('52.00')),
#  ('Chad', 2019, Decimal('11.31'), Decimal('52.33')),
#  ('Chad', 2020, Decimal('10.72'), Decimal('52.67')),
#  ('Chile', 2015, Decimal('242.50'), Decimal('99.00')),
#  ('Chile', 2016, Decimal('249.30'), Decimal('99.67')),
#  ('Chile', 2017, Decimal('276.36'), Decimal('100.00')),
#  ('Chile', 2018, Decimal('295.40'), Decimal('100.00')),
#  ('Chile', 2019, Decimal('278.58'), Decimal('100.00')),
#  ('Chile', 2020, Decimal('252.73'), Decimal('100.00')),
#  ('China', 2015, Decimal('11061.55'), Decimal('91.33')),
#  ('China', 2016, Decimal('11233.28'), Decimal('91.33')),
#  ('China', 2017, Decimal('12310.41'), Decimal('92.00')),
#  ('China', 2018, Decimal('13894.82'), Decimal('92.67')),
#  ('China', 2019, Decimal('14279.94'), Decimal('93.33')),
#  ('China', 2020, Decimal('14687.67'), Decimal('93.67')),
#  ('Colombia', 2015, Decimal('293.48'), Decimal('93.00')),
#  ('Colombia', 2016, Decimal('282.83'), Decimal('93.67')),
#  ('Colombia', 2017, Decimal('311.88'), Decimal('94.00')),
#  ('Colombia', 2018, Decimal('334.20'), Decimal('94.00')),
#  ('Colombia', 2019, Decimal('323.11'), Decimal('94.33')),
#  ('Colombia', 2020, Decimal('270.30'), Decimal('94.67')),
#  ('Comoros', 2015, Decimal('0.97'), Decimal('81.67')),
#  ('Comoros', 2016, Decimal('1.01'), Decimal('81.67')),
#  ('Comoros', 2017, Decimal('1.08'), Decimal('81.67')),
#  ('Comoros', 2018, Decimal('1.19'), Decimal('81.67')),
#  ('Comoros', 2019, Decimal('1.20'), Decimal('81.67')),
#  ('Congo', 2015, None, Decimal('66.33')),
#  ('Congo', 2016, None, Decimal('67.67')),
#  ('Congo', 2017, None, Decimal('68.67')),
#  ('Congo', 2018, None, Decimal('68.67')),
#  ('Congo', 2019, None, Decimal('69.00')),
#  ('Congo', 2020, None, Decimal('69.00')),
#  ('Cook Islands', 2015, None, Decimal('100.00')),
#  ('Cook Islands', 2016, None, Decimal('100.00')),
#  ('Cook Islands', 2017, None, Decimal('100.00')),
#  ('Cook Islands', 2018, None, Decimal('100.00')),
#  ('Cook Islands', 2019, None, Decimal('100.00')),
#  ('Cook Islands', 2020, None, Decimal('100.00')),
#  ('Costa Rica', 2015, Decimal('56.44'), Decimal('99.00')),
#  ('Costa Rica', 2016, Decimal('58.85'), Decimal('99.67')),
#  ('Costa Rica', 2017, Decimal('60.52'), Decimal('100.00')),
#  ('Costa Rica', 2018, Decimal('62.42'), Decimal('100.00')),
#  ('Costa Rica', 2019, Decimal('64.42'), Decimal('100.00')),
#  ('Costa Rica', 2020, Decimal('62.16'), Decimal('100.00')),
#  ("Côte d'Ivoire", 2015, None, Decimal('71.33')),
#  ("Côte d'Ivoire", 2016, None, Decimal('71.00')),
#  ("Côte d'Ivoire", 2017, None, Decimal('71.00')),
#  ("Côte d'Ivoire", 2018, None, Decimal('71.00')),
#  ("Côte d'Ivoire", 2019, None, Decimal('70.67')),
#  ("Côte d'Ivoire", 2020, None, Decimal('70.67')),
#  ('Cuba', 2015, Decimal('87.13'), Decimal('94.67')),
#  ('Cuba', 2016, Decimal('91.37'), Decimal('95.00')),
#  ('Cuba', 2017, Decimal('96.85'), Decimal('95.33')),
#  ('Cuba', 2018, Decimal('100.05'), Decimal('96.00')),
#  ('Cuba', 2019, Decimal('103.43'), Decimal('96.33')),
#  ('Cuba', 2020, Decimal('107.35'), Decimal('96.33')),
#  ('Curaçao', 2015, None, Decimal('99.00')),
#  ('Curaçao', 2016, None, Decimal('99.00')),
#  ('Curaçao', 2017, None, Decimal('99.00')),
#  ('Cyprus', 2015, Decimal('19.91'), Decimal('100.00')),
#  ('Cyprus', 2016, Decimal('21.05'), Decimal('100.00')),
#  ('Cyprus', 2017, Decimal('22.95'), Decimal('100.00')),
#  ('Cyprus', 2018, Decimal('25.60'), Decimal('100.00')),
#  ('Cyprus', 2019, Decimal('25.94'), Decimal('100.00')),
#  ('Cyprus', 2020, Decimal('25.01'), Decimal('100.00')),
#  ("Democratic People's Republic of Korea", 2015, None, Decimal('94.67')),
#  ("Democratic People's Republic of Korea", 2016, None, Decimal('94.33')),
#  ("Democratic People's Republic of Korea", 2017, None, Decimal('94.00')),
#  ("Democratic People's Republic of Korea", 2018, None, Decimal('93.33')),
#  ("Democratic People's Republic of Korea", 2019, None, Decimal('93.33')),
#  ("Democratic People's Republic of Korea", 2020, None, Decimal('93.33')),
#  ('Democratic Republic of the Congo', 2015, None, Decimal('45.33')),
#  ('Democratic Republic of the Congo', 2016, None, Decimal('45.67')),
#  ('Democratic Republic of the Congo', 2017, None, Decimal('46.00')),
#  ('Democratic Republic of the Congo', 2018, None, Decimal('46.67')),
#  ('Democratic Republic of the Congo', 2019, None, Decimal('47.00')),
#  ('Democratic Republic of the Congo', 2020, None, Decimal('47.67')),
#  ('Djibouti', 2015, Decimal('2.42'), Decimal('69.67')),
#  ('Djibouti', 2016, Decimal('2.60'), Decimal('69.33')),
#  ('Djibouti', 2017, Decimal('2.76'), Decimal('69.33')),
#  ('Djibouti', 2018, Decimal('2.91'), Decimal('69.33')),
#  ('Djibouti', 2019, Decimal('3.09'), Decimal('69.00')),
#  ('Djibouti', 2020, Decimal('3.18'), Decimal('69.00')),
#  ('Dominica', 2015, Decimal('0.54'), Decimal('95.00')),
#  ('Dominica', 2016, Decimal('0.58'), Decimal('95.00')),
#  ('Dominica', 2017, Decimal('0.52'), Decimal('95.00')),
#  ('Dominican Republic', 2015, Decimal('71.16'), Decimal('94.33')),
#  ('Dominican Republic', 2016, Decimal('75.70'), Decimal('94.67')),
#  ('Dominican Republic', 2017, Decimal('80.00'), Decimal('94.67')),
#  ('Dominican Republic', 2018, Decimal('85.56'), Decimal('95.00')),
#  ('Dominican Republic', 2019, Decimal('88.94'), Decimal('95.00')),
#  ('Dominican Republic', 2020, Decimal('78.84'), Decimal('95.00')),
#  ('Ecuador', 2015, Decimal('99.29'), Decimal('91.67')),
#  ('Ecuador', 2016, Decimal('99.94'), Decimal('92.33')),
#  ('Ecuador', 2017, Decimal('104.30'), Decimal('92.67')),
#  ('Ecuador', 2018, Decimal('107.56'), Decimal('93.33')),
#  ('Ecuador', 2019, Decimal('108.11'), Decimal('93.67')),
#  ('Ecuador', 2020, Decimal('99.29'), Decimal('94.00')),
#  ('Egypt', 2015, None, Decimal('99.33')),
#  ('Egypt', 2016, None, Decimal('99.33')),
#  ('Egypt', 2017, None, Decimal('99.33')),
#  ('Egypt', 2018, None, Decimal('99.33')),
#  ('Egypt', 2019, None, Decimal('99.33')),
#  ('Egypt', 2020, None, Decimal('99.33')),
#  ('El Salvador', 2015, Decimal('23.44'), Decimal('94.33')),
#  ('El Salvador', 2016, Decimal('24.19'), Decimal('95.33')),
#  ('El Salvador', 2017, Decimal('24.98'), Decimal('96.00')),
#  ('El Salvador', 2018, Decimal('26.02'), Decimal('97.00')),
#  ('El Salvador', 2019, Decimal('26.88'), Decimal('97.00')),
#  ('El Salvador', 2020, Decimal('24.56'), Decimal('97.00')),
#  ('Equatorial Guinea', 2015, Decimal('13.19'), Decimal('57.67')),
#  ('Equatorial Guinea', 2016, Decimal('11.24'), Decimal('57.67')),
#  ('Equatorial Guinea', 2017, Decimal('12.20'), Decimal('58.00')),
#  ('Eritrea', 2015, None, Decimal('56.33')),
#  ('Eritrea', 2016, None, Decimal('56.67')),
#  ('Eswatini', 2015, Decimal('4.06'), Decimal('73.33')),
#  ('Eswatini', 2016, Decimal('3.82'), Decimal('74.00')),
#  ('Eswatini', 2017, Decimal('4.40'), Decimal('75.00')),
#  ('Eswatini', 2018, Decimal('4.67'), Decimal('75.67')),
#  ('Eswatini', 2019, Decimal('4.50'), Decimal('76.67')),
#  ('Eswatini', 2020, Decimal('3.98'), Decimal('76.67')),
#  ('Ethiopia', 2015, Decimal('64.59'), Decimal('52.00')),
#  ('Ethiopia', 2016, Decimal('74.30'), Decimal('53.33')),
#  ('Ethiopia', 2017, Decimal('81.77'), Decimal('54.67')),
#  ('Ethiopia', 2018, Decimal('84.27'), Decimal('55.67')),
#  ('Ethiopia', 2019, Decimal('95.91'), Decimal('57.00')),
#  ('Ethiopia', 2020, Decimal('107.66'), Decimal('58.00')),
#  ('Falkland Islands (Malvinas)', 2015, None, Decimal('91.00')),
#  ('Falkland Islands (Malvinas)', 2016, None, Decimal('91.00')),
#  ('Falkland Islands (Malvinas)', 2017, None, Decimal('91.00')),
#  ('Falkland Islands (Malvinas)', 2018, None, Decimal('91.00')),
#  ('Falkland Islands (Malvinas)', 2019, None, Decimal('91.00')),
#  ('Falkland Islands (Malvinas)', 2020, None, Decimal('91.00')),
#  ('Fiji', 2015, Decimal('4.68'), Decimal('93.67')),
#  ('Fiji', 2016, Decimal('4.93'), Decimal('93.67')),
#  ('Fiji', 2017, Decimal('5.35'), Decimal('93.67')),
#  ('Fiji', 2018, Decimal('5.58'), Decimal('93.67')),
#  ('Fiji', 2019, Decimal('5.48'), Decimal('93.67')),
#  ('Fiji', 2020, Decimal('4.48'), Decimal('93.67')),
#  ('French Guiana', 2015, None, Decimal('94.00')),
#  ('French Guiana', 2016, None, Decimal('94.00')),
#  ('French Guiana', 2017, None, Decimal('94.00')),
#  ('French Guiana', 2018, None, Decimal('94.00')),
#  ('French Guiana', 2019, None, Decimal('94.00')),
#  ('French Guiana', 2020, None, Decimal('94.00')),
#  ('French Polynesia', 2015, Decimal('5.33'), Decimal('100.00')),
#  ('French Polynesia', 2016, Decimal('5.50'), Decimal('100.00')),
#  ('French Polynesia', 2017, Decimal('5.83'), Decimal('100.00')),
#  ('French Polynesia', 2018, Decimal('6.14'), Decimal('100.00')),
#  ('French Polynesia', 2019, Decimal('6.00'), Decimal('100.00')),
#  ('French Polynesia', 2020, Decimal('5.71'), Decimal('100.00')),
#  ('Gabon', 2015, Decimal('14.38'), Decimal('72.00')),
#  ('Gabon', 2016, Decimal('14.02'), Decimal('72.33')),
#  ('Gabon', 2017, Decimal('14.93'), Decimal('73.00')),
#  ('Gabon', 2018, Decimal('16.87'), Decimal('73.00')),
#  ('Gabon', 2019, Decimal('16.87'), Decimal('73.33')),
#  ('Gabon', 2020, Decimal('15.31'), Decimal('73.33')),
#  ('Gambia', 2015, None, Decimal('78.00')),
#  ('Gambia', 2016, None, Decimal('78.33')),
#  ('Gambia', 2017, None, Decimal('78.67')),
#  ('Gambia', 2018, None, Decimal('78.67')),
#  ('Gambia', 2019, None, Decimal('79.33')),
#  ('Gambia', 2020, None, Decimal('79.33')),
#  ('Georgia', 2015, Decimal('14.95'), Decimal('95.33')),
#  ('Georgia', 2016, Decimal('15.14'), Decimal('96.00')),
#  ('Georgia', 2017, Decimal('16.24'), Decimal('96.67')),
#  ('Georgia', 2018, Decimal('17.60'), Decimal('96.67')),
#  ('Georgia', 2019, Decimal('17.47'), Decimal('96.67')),
#  ('Georgia', 2020, Decimal('15.84'), Decimal('96.67')),
#  ('Ghana', 2015, Decimal('49.41'), Decimal('79.33')),
#  ('Ghana', 2016, Decimal('56.17'), Decimal('80.33')),
#  ('Ghana', 2017, Decimal('60.41'), Decimal('81.33')),
#  ('Ghana', 2018, Decimal('67.30'), Decimal('82.67')),
#  ('Ghana', 2019, Decimal('68.34'), Decimal('83.67')),
#  ('Ghana', 2020, Decimal('70.04'), Decimal('84.67')),
#  ('Greenland', 2015, Decimal('2.50'), Decimal('100.00')),
#  ('Greenland', 2016, Decimal('2.71'), Decimal('100.00')),
#  ('Greenland', 2017, Decimal('2.85'), Decimal('100.00')),
#  ('Greenland', 2018, Decimal('3.06'), Decimal('100.00')),
#  ('Greenland', 2019, Decimal('2.99'), Decimal('100.00')),
#  ('Greenland', 2020, Decimal('3.08'), Decimal('100.00')),
#  ('Grenada', 2015, Decimal('1.00'), Decimal('96.00')),
#  ('Grenada', 2016, Decimal('1.06'), Decimal('96.00')),
#  ('Grenada', 2017, Decimal('1.13'), Decimal('96.00')),
#  ('Guadeloupe', 2015, None, Decimal('100.00')),
#  ('Guadeloupe', 2016, None, Decimal('100.00')),
#  ('Guadeloupe', 2017, None, Decimal('100.00')),
#  ('Guadeloupe', 2018, None, Decimal('100.00')),
#  ('Guadeloupe', 2019, None, Decimal('100.00')),
#  ('Guadeloupe', 2020, None, Decimal('100.00')),
#  ('Guam', 2015, Decimal('5.80'), Decimal('100.00')),
#  ('Guam', 2016, Decimal('5.90'), Decimal('100.00')),
#  ('Guam', 2017, Decimal('6.01'), Decimal('100.00')),
#  ('Guam', 2018, Decimal('6.06'), Decimal('100.00')),
#  ('Guam', 2019, Decimal('6.37'), Decimal('100.00')),
#  ('Guam', 2020, Decimal('5.89'), Decimal('100.00')),
#  ('Guatemala', 2015, Decimal('62.19'), Decimal('92.00')),
#  ('Guatemala', 2016, Decimal('66.05'), Decimal('92.33')),
#  ('Guatemala', 2017, Decimal('71.65'), Decimal('92.67')),
#  ('Guatemala', 2018, Decimal('73.33'), Decimal('93.00')),
#  ('Guatemala', 2019, Decimal('77.17'), Decimal('94.00')),
#  ('Guatemala', 2020, Decimal('77.63'), Decimal('94.00')),
#  ('Guinea', 2015, Decimal('8.79'), Decimal('67.00')),
#  ('Guinea', 2016, Decimal('8.60'), Decimal('67.00')),
#  ('Guinea', 2017, Decimal('10.32'), Decimal('67.33')),
#  ('Guinea', 2018, Decimal('11.86'), Decimal('67.00')),
#  ('Guinea', 2019, Decimal('13.44'), Decimal('67.00')),
#  ('Guinea', 2020, Decimal('14.18'), Decimal('67.33')),
#  ('Guinea-Bissau', 2015, Decimal('1.05'), Decimal('60.00')),
#  ('Guinea-Bissau', 2016, Decimal('1.18'), Decimal('60.33')),
#  ('Guinea-Bissau', 2017, Decimal('1.35'), Decimal('60.00')),
#  ('Guinea-Bissau', 2018, Decimal('1.50'), Decimal('60.00')),
#  ('Guinea-Bissau', 2019, Decimal('1.44'), Decimal('60.00')),
#  ('Guinea-Bissau', 2020, Decimal('1.43'), Decimal('60.00')),
#  ('Guyana', 2015, Decimal('4.28'), Decimal('96.00')),
#  ('Guyana', 2016, Decimal('4.48'), Decimal('96.67')),
#  ('Guyana', 2017, Decimal('4.75'), Decimal('96.67')),
#  ('Guyana', 2018, Decimal('4.79'), Decimal('96.67')),
#  ('Guyana', 2019, Decimal('5.17'), Decimal('96.67')),
#  ('Guyana', 2020, Decimal('5.47'), Decimal('96.67')),
#  ('Haiti', 2015, Decimal('14.83'), Decimal('64.00')),
#  ('Haiti', 2016, Decimal('13.99'), Decimal('64.33')),
#  ('Haiti', 2017, Decimal('15.04'), Decimal('64.33')),
#  ('Haiti', 2018, Decimal('16.46'), Decimal('64.67')),
#  ('Haiti', 2019, Decimal('14.79'), Decimal('64.67')),
#  ('Haiti', 2020, Decimal('14.51'), Decimal('65.00')),
#  ('Honduras', 2015, Decimal('20.98'), Decimal('92.67')),
#  ('Honduras', 2016, Decimal('21.72'), Decimal('93.33')),
#  ('Honduras', 2017, Decimal('23.14'), Decimal('93.67')),
#  ('Honduras', 2018, Decimal('24.07'), Decimal('94.33')),
#  ('Honduras', 2019, Decimal('25.09'), Decimal('94.67')),
#  ('Honduras', 2020, Decimal('23.83'), Decimal('95.33')),
#  ('India', 2015, Decimal('2103.59'), Decimal('89.00')),
#  ('India', 2016, Decimal('2294.80'), Decimal('89.33')),
#  ('India', 2017, Decimal('2651.47'), Decimal('90.00')),
#  ('India', 2018, Decimal('2702.93'), Decimal('90.33')),
#  ('India', 2019, Decimal('2831.55'), Decimal('90.67')),
#  ('India', 2020, Decimal('2667.69'), Decimal('91.00')),
#  ('Indonesia', 2015, Decimal('860.85'), Decimal('88.33')),
#  ('Indonesia', 2016, Decimal('931.88'), Decimal('89.00')),
#  ('Indonesia', 2017, Decimal('1015.62'), Decimal('89.67')),
#  ('Indonesia', 2018, Decimal('1042.27'), Decimal('90.67')),
#  ('Indonesia', 2019, Decimal('1119.10'), Decimal('91.33')),
#  ('Indonesia', 2020, Decimal('1058.69'), Decimal('92.00')),
#  ('Iran (Islamic Republic of)', 2015, None, Decimal('95.67')),
#  ('Iran (Islamic Republic of)', 2016, None, Decimal('96.00')),
#  ('Iran (Islamic Republic of)', 2017, None, Decimal('96.33')),
#  ('Iran (Islamic Republic of)', 2018, None, Decimal('96.33')),
#  ('Iran (Islamic Republic of)', 2019, None, Decimal('96.33')),
#  ('Iran (Islamic Republic of)', 2020, None, Decimal('96.67')),
#  ('Iraq', 2015, Decimal('166.77'), Decimal('92.33')),
#  ('Iraq', 2016, Decimal('166.60'), Decimal('93.67')),
#  ('Iraq', 2017, Decimal('187.22'), Decimal('94.67')),
#  ('Iraq', 2018, Decimal('227.37'), Decimal('95.67')),
#  ('Iraq', 2019, Decimal('233.64'), Decimal('97.00')),
#  ('Iraq', 2020, Decimal('184.37'), Decimal('97.67')),
#  ('Israel', 2015, Decimal('303.41'), Decimal('100.00')),
#  ('Israel', 2016, Decimal('322.10'), Decimal('100.00')),
#  ('Israel', 2017, Decimal('358.25'), Decimal('100.00')),
#  ('Israel', 2018, Decimal('376.69'), Decimal('100.00')),
#  ('Israel', 2019, Decimal('402.47'), Decimal('100.00')),
#  ('Israel', 2020, Decimal('413.27'), Decimal('100.00')),
#  ('Jamaica', 2015, Decimal('14.19'), Decimal('90.00')),
#  ('Jamaica', 2016, Decimal('14.08'), Decimal('90.33')),
#  ('Jamaica', 2017, Decimal('14.81'), Decimal('90.33')),
#  ('Jamaica', 2018, Decimal('15.73'), Decimal('90.33')),
#  ('Jamaica', 2019, Decimal('15.83'), Decimal('90.33')),
#  ('Jamaica', 2020, Decimal('13.81'), Decimal('90.33')),
#  ('Japan', 2015, Decimal('4444.93'), Decimal('99.00')),
#  ('Japan', 2016, Decimal('5003.68'), Decimal('99.00')),
#  ('Japan', 2017, Decimal('4930.84'), Decimal('99.00')),
#  ('Japan', 2018, Decimal('5037.84'), Decimal('99.00')),
#  ('Japan', 2019, Decimal('5123.32'), Decimal('99.00')),
#  ('Japan', 2020, Decimal('5040.11'), Decimal('99.00')),
#  ('Jordan', 2015, Decimal('38.59'), Decimal('98.33')),
#  ('Jordan', 2016, Decimal('39.89'), Decimal('98.33')),
#  ('Jordan', 2017, Decimal('41.61'), Decimal('98.33')),
#  ('Jordan', 2018, Decimal('43.37'), Decimal('98.33')),
#  ('Jordan', 2019, Decimal('44.99'), Decimal('98.33')),
#  ('Jordan', 2020, Decimal('44.18'), Decimal('98.33')),
#  ('Kazakhstan', 2015, Decimal('184.39'), Decimal('94.67')),
#  ('Kazakhstan', 2016, Decimal('137.28'), Decimal('94.67')),
#  ('Kazakhstan', 2017, Decimal('166.81'), Decimal('95.00')),
#  ('Kazakhstan', 2018, Decimal('179.34'), Decimal('95.00')),
#  ('Kazakhstan', 2019, Decimal('181.67'), Decimal('95.00')),
#  ('Kazakhstan', 2020, Decimal('171.08'), Decimal('95.00')),
#  ('Kenya', 2015, Decimal('70.12'), Decimal('64.33')),
#  ('Kenya', 2016, Decimal('74.82'), Decimal('65.00')),
#  ('Kenya', 2017, Decimal('82.04'), Decimal('65.67')),
#  ('Kenya', 2018, Decimal('92.20'), Decimal('65.67')),
#  ('Kenya', 2019, Decimal('100.38'), Decimal('66.33')),
#  ('Kenya', 2020, Decimal('100.67'), Decimal('67.00')),
#  ('Kiribati', 2015, Decimal('0.17'), Decimal('73.67')),
#  ('Kiribati', 2016, Decimal('0.18'), Decimal('74.33')),
#  ('Kiribati', 2017, Decimal('0.19'), Decimal('75.00')),
#  ('Kiribati', 2018, Decimal('0.20'), Decimal('75.33')),
#  ('Kiribati', 2019, Decimal('0.18'), Decimal('76.00')),
#  ('Kiribati', 2020, Decimal('0.18'), Decimal('77.00')),
#  ('Kuwait', 2015, Decimal('114.57'), Decimal('100.00')),
#  ('Kuwait', 2016, Decimal('109.42'), Decimal('100.00')),
#  ('Kuwait', 2017, Decimal('120.71'), Decimal('100.00')),
#  ('Kuwait', 2018, Decimal('138.18'), Decimal('100.00')),
#  ('Kuwait', 2019, Decimal('136.20'), Decimal('100.00')),
#  ('Kuwait', 2020, Decimal('105.96'), Decimal('100.00')),
#  ('Kyrgyzstan', 2015, None, Decimal('89.67')),
#  ('Kyrgyzstan', 2016, None, Decimal('90.33')),
#  ('Kyrgyzstan', 2017, None, Decimal('91.00')),
#  ('Kyrgyzstan', 2018, None, Decimal('91.33')),
#  ('Kyrgyzstan', 2019, None, Decimal('91.67')),
#  ('Kyrgyzstan', 2020, None, Decimal('92.67')),
#  ("Lao People's Democratic Republic", 2015, None, Decimal('79.67')),
#  ("Lao People's Democratic Republic", 2016, None, Decimal('82.00')),
#  ("Lao People's Democratic Republic", 2017, None, Decimal('83.33')),
#  ("Lao People's Democratic Republic", 2018, None, Decimal('85.00')),
#  ("Lao People's Democratic Republic", 2019, None, Decimal('86.67')),
#  ("Lao People's Democratic Republic", 2020, None, Decimal('86.67')),
#  ('Lebanon', 2015, Decimal('49.93'), Decimal('91.00')),
#  ('Lebanon', 2016, Decimal('51.15'), Decimal('92.00')),
#  ('Lebanon', 2017, Decimal('53.03'), Decimal('92.00')),
#  ('Lebanon', 2018, Decimal('54.90'), Decimal('92.00')),
#  ('Lebanon', 2019, Decimal('51.95'), Decimal('93.00')),
#  ('Lebanon', 2020, Decimal('31.71'), Decimal('93.00')),
#  ('Lesotho', 2015, Decimal('2.36'), Decimal('74.67')),
#  ('Lesotho', 2016, Decimal('2.11'), Decimal('75.00')),
#  ('Lesotho', 2017, Decimal('2.31'), Decimal('75.33')),
#  ('Lesotho', 2018, Decimal('2.55'), Decimal('76.00')),
#  ('Lesotho', 2019, Decimal('2.45'), Decimal('76.00')),
#  ('Lesotho', 2020, Decimal('2.23'), Decimal('76.33')),
#  ('Liberia', 2015, Decimal('3.23'), Decimal('72.67')),
#  ('Liberia', 2016, Decimal('3.40'), Decimal('73.00')),
#  ('Liberia', 2017, Decimal('3.39'), Decimal('74.00')),
#  ('Liberia', 2018, Decimal('3.42'), Decimal('74.00')),
#  ('Liberia', 2019, Decimal('3.32'), Decimal('75.00')),
#  ('Liberia', 2020, Decimal('3.04'), Decimal('75.00')),
#  ('Libya', 2015, Decimal('48.72'), Decimal('97.00')),
#  ('Libya', 2016, Decimal('49.91'), Decimal('98.00')),
#  ('Libya', 2017, Decimal('67.16'), Decimal('99.00')),
#  ('Libya', 2018, Decimal('76.68'), Decimal('100.00')),
#  ('Libya', 2019, Decimal('69.25'), Decimal('100.00')),
#  ('Libya', 2020, Decimal('50.36'), Decimal('100.00')),
#  ('Madagascar', 2015, Decimal('11.32'), Decimal('53.33')),
#  ('Madagascar', 2016, Decimal('11.85'), Decimal('54.00')),
#  ('Madagascar', 2017, Decimal('13.18'), Decimal('54.67')),
#  ('Madagascar', 2018, Decimal('13.76'), Decimal('55.33')),
#  ('Madagascar', 2019, Decimal('14.10'), Decimal('56.00')),
#  ('Madagascar', 2020, Decimal('13.05'), Decimal('56.33')),
#  ('Malawi', 2015, Decimal('6.37'), Decimal('71.33')),
#  ('Malawi', 2016, Decimal('5.43'), Decimal('72.00')),
#  ('Malawi', 2017, Decimal('8.94'), Decimal('72.67')),
#  ('Malawi', 2018, Decimal('9.88'), Decimal('73.33')),
#  ('Malawi', 2019, Decimal('11.03'), Decimal('73.67')),
#  ('Malawi', 2020, Decimal('12.18'), Decimal('74.33')),
#  ('Malaysia', 2015, Decimal('301.35'), Decimal('95.67')),
#  ('Malaysia', 2016, Decimal('301.26'), Decimal('95.67')),
#  ('Malaysia', 2017, Decimal('319.11'), Decimal('95.67')),
#  ('Malaysia', 2018, Decimal('358.79'), Decimal('95.33')),
#  ('Malaysia', 2019, Decimal('365.18'), Decimal('95.33')),
#  ('Malaysia', 2020, Decimal('337.34'), Decimal('95.33')),
#  ('Maldives', 2015, Decimal('4.11'), Decimal('99.00')),
#  ('Maldives', 2016, Decimal('4.38'), Decimal('99.00')),
#  ('Maldives', 2017, Decimal('4.75'), Decimal('99.33')),
#  ('Maldives', 2018, Decimal('5.30'), Decimal('99.33')),
#  ('Maldives', 2019, Decimal('5.61'), Decimal('99.67')),
#  ('Maldives', 2020, Decimal('3.75'), Decimal('99.67')),
#  ('Mali', 2015, Decimal('13.10'), Decimal('76.00')),
#  ('Mali', 2016, Decimal('14.03'), Decimal('77.67')),
#  ('Mali', 2017, Decimal('15.37'), Decimal('79.33')),
#  ('Mali', 2018, Decimal('17.07'), Decimal('80.67')),
#  ('Mali', 2019, Decimal('17.28'), Decimal('82.00')),
#  ('Mali', 2020, Decimal('17.47'), Decimal('83.67')),
#  ('Marshall Islands', 2015, Decimal('0.18'), Decimal('89.33')),
#  ('Marshall Islands', 2016, Decimal('0.20'), Decimal('89.67')),
#  ('Marshall Islands', 2017, Decimal('0.21'), Decimal('89.67')),
#  ('Marshall Islands', 2018, Decimal('0.22'), Decimal('90.00')),
#  ('Marshall Islands', 2019, Decimal('0.23'), Decimal('90.00')),
#  ('Marshall Islands', 2020, Decimal('0.24'), Decimal('90.00')),
#  ('Martinique', 2015, None, Decimal('100.00')),
#  ('Martinique', 2016, None, Decimal('100.00')),
#  ('Martinique', 2017, None, Decimal('100.00')),
#  ('Martinique', 2018, None, Decimal('100.00')),
#  ('Martinique', 2019, None, Decimal('100.00')),
#  ('Martinique', 2020, None, Decimal('100.00')),
#  ('Mauritania', 2015, Decimal('6.17'), Decimal('66.67')),
#  ('Mauritania', 2016, Decimal('6.40'), Decimal('68.33')),
#  ('Mauritania', 2017, Decimal('6.80'), Decimal('70.00')),
#  ('Mauritania', 2018, Decimal('7.47'), Decimal('70.00')),
#  ('Mauritania', 2019, Decimal('8.07'), Decimal('70.00')),
#  ('Mauritania', 2020, Decimal('8.41'), Decimal('70.33')),
#  ('Mauritius', 2015, Decimal('12.01'), Decimal('100.00')),
#  ('Mauritius', 2016, Decimal('12.59'), Decimal('100.00')),
#  ('Mauritius', 2017, Decimal('13.71'), Decimal('100.00')),
#  ('Mauritius', 2018, Decimal('14.74'), Decimal('100.00')),
#  ('Mauritius', 2019, Decimal('14.44'), Decimal('100.00')),
#  ('Mauritius', 2020, Decimal('11.40'), Decimal('100.00')),
#  ('Mayotte', 2015, None, Decimal('97.00')),
#  ('Mayotte', 2016, None, Decimal('97.00')),
#  ('Mayotte', 2017, None, Decimal('97.00')),
#  ('Mayotte', 2018, None, Decimal('96.00')),
#  ('Mayotte', 2019, None, Decimal('96.00')),
#  ('Mayotte', 2020, None, Decimal('96.00')),
#  ('Mexico', 2015, Decimal('1171.87'), Decimal('96.67')),
#  ('Mexico', 2016, Decimal('1078.49'), Decimal('97.33')),
#  ('Mexico', 2017, Decimal('1158.91'), Decimal('98.00')),
#  ('Mexico', 2018, Decimal('1222.41'), Decimal('98.33')),
#  ('Mexico', 2019, Decimal('1269.01'), Decimal('98.67')),
#  ('Mexico', 2020, Decimal('1090.52'), Decimal('99.33')),
#  ('Micronesia (Federated States of)', 2015, None, Decimal('88.00')),
#  ('Micronesia (Federated States of)', 2016, None, Decimal('88.00')),
#  ('Micronesia (Federated States of)', 2017, None, Decimal('88.00')),
#  ('Micronesia (Federated States of)', 2018, None, Decimal('88.00')),
#  ('Micronesia (Federated States of)', 2019, None, Decimal('88.00')),
#  ('Mongolia', 2015, Decimal('11.62'), Decimal('75.67')),
#  ('Mongolia', 2016, Decimal('11.18'), Decimal('77.00')),
#  ('Mongolia', 2017, Decimal('11.48'), Decimal('78.00')),
#  ('Mongolia', 2018, Decimal('13.18'), Decimal('79.00')),
#  ('Mongolia', 2019, Decimal('14.21'), Decimal('80.00')),
#  ('Mongolia', 2020, Decimal('13.31'), Decimal('81.00')),
#  ('Montserrat', 2015, None, Decimal('98.00')),
#  ('Montserrat', 2016, None, Decimal('98.00')),
#  ('Montserrat', 2017, None, Decimal('98.00')),
#  ('Montserrat', 2018, None, Decimal('98.00')),
#  ('Montserrat', 2019, None, Decimal('98.00')),
#  ('Montserrat', 2020, None, Decimal('98.00')),
#  ('Morocco', 2015, Decimal('110.41'), Decimal('81.33')),
#  ('Morocco', 2016, Decimal('111.57'), Decimal('83.00')),
#  ('Morocco', 2017, Decimal('118.54'), Decimal('84.00')),
#  ('Morocco', 2018, Decimal('127.34'), Decimal('85.67')),
#  ('Morocco', 2019, Decimal('128.92'), Decimal('87.33')),
#  ('Morocco', 2020, Decimal('121.35'), Decimal('88.33')),
#  ('Mozambique', 2015, Decimal('15.95'), Decimal('55.67')),
#  ('Mozambique', 2016, Decimal('11.94'), Decimal('58.00')),
#  ('Mozambique', 2017, Decimal('13.22'), Decimal('60.00')),
#  ('Mozambique', 2018, Decimal('14.85'), Decimal('62.33')),
#  ('Mozambique', 2019, Decimal('15.39'), Decimal('64.33')),
#  ('Mozambique', 2020, Decimal('14.03'), Decimal('66.67')),
#  ('Myanmar', 2015, Decimal('63.05'), Decimal('76.33')),
#  ('Myanmar', 2016, Decimal('60.29'), Decimal('78.33')),
#  ('Myanmar', 2017, Decimal('61.45'), Decimal('80.33')),
#  ('Myanmar', 2018, Decimal('67.14'), Decimal('82.33')),
#  ('Myanmar', 2019, Decimal('68.70'), Decimal('84.00')),
#  ('Myanmar', 2020, Decimal('78.93'), Decimal('85.67')),
#  ('Namibia', 2015, Decimal('11.34'), Decimal('83.33')),
#  ('Namibia', 2016, Decimal('10.72'), Decimal('83.00')),
#  ('Namibia', 2017, Decimal('12.90'), Decimal('83.33')),
#  ('Namibia', 2018, Decimal('13.68'), Decimal('83.67')),
#  ('Namibia', 2019, Decimal('12.54'), Decimal('83.67')),
#  ('Namibia', 2020, Decimal('10.58'), Decimal('83.67')),
#  ('Nauru', 2015, Decimal('0.09'), Decimal('100.00')),
#  ('Nauru', 2016, Decimal('0.10'), Decimal('100.00')),
#  ('Nauru', 2017, Decimal('0.11'), Decimal('100.00')),
#  ('Nauru', 2018, Decimal('0.12'), Decimal('100.00')),
#  ('Nauru', 2019, Decimal('0.12'), Decimal('100.00')),
#  ('Nauru', 2020, Decimal('0.11'), Decimal('100.00')),
#  ('Nepal', 2015, Decimal('24.36'), Decimal('88.33')),
#  ('Nepal', 2016, Decimal('24.52'), Decimal('88.67')),
#  ('Nepal', 2017, Decimal('28.97'), Decimal('89.00')),
#  ('Nepal', 2018, Decimal('33.11'), Decimal('89.33')),
#  ('Nepal', 2019, Decimal('34.19'), Decimal('90.00')),
#  ('Nepal', 2020, Decimal('33.43'), Decimal('90.00')),
#  ('New Caledonia', 2015, Decimal('8.74'), Decimal('98.00')),
#  ('New Caledonia', 2016, Decimal('8.72'), Decimal('98.00')),
#  ('New Caledonia', 2017, Decimal('9.17'), Decimal('99.00')),
#  ('New Caledonia', 2018, Decimal('9.85'), Decimal('99.00')),
#  ('New Caledonia', 2019, Decimal('9.44'), Decimal('99.00')),
#  ('New Caledonia', 2020, Decimal('9.44'), Decimal('99.00')),
#  ('New Zealand', 2015, Decimal('178.06'), Decimal('100.00')),
#  ('New Zealand', 2016, Decimal('188.84'), Decimal('100.00')),
#  ('New Zealand', 2017, Decimal('206.62'), Decimal('100.00')),
#  ('New Zealand', 2018, Decimal('211.95'), Decimal('100.00')),
#  ('New Zealand', 2019, Decimal('213.43'), Decimal('100.00')),
#  ('New Zealand', 2020, Decimal('211.73'), Decimal('100.00')),
#  ('Nicaragua', 2015, Decimal('12.76'), Decimal('79.33')),
#  ('Nicaragua', 2016, Decimal('13.29'), Decimal('79.00')),
#  ('Nicaragua', 2017, Decimal('13.79'), Decimal('79.00')),
#  ('Nicaragua', 2018, Decimal('13.03'), Decimal('79.33')),
#  ('Nicaragua', 2019, Decimal('12.60'), Decimal('79.33')),
#  ('Nicaragua', 2020, Decimal('12.59'), Decimal('79.33')),
#  ('Niger', 2015, Decimal('9.68'), Decimal('56.67')),
#  ('Niger', 2016, Decimal('10.40'), Decimal('57.00')),
#  ('Niger', 2017, Decimal('11.19'), Decimal('57.00')),
#  ('Niger', 2018, Decimal('12.81'), Decimal('57.00')),
#  ('Niger', 2019, Decimal('12.92'), Decimal('57.33')),
#  ('Niger', 2020, Decimal('13.74'), Decimal('57.33')),
#  ('Nigeria', 2015, Decimal('493.03'), Decimal('69.00')),
#  ('Nigeria', 2016, Decimal('404.65'), Decimal('71.00')),
#  ('Nigeria', 2017, Decimal('375.75'), Decimal('72.33')),
#  ('Nigeria', 2018, Decimal('421.74'), Decimal('74.00')),
#  ('Nigeria', 2019, Decimal('448.12'), Decimal('75.67')),
#  ('Nigeria', 2020, Decimal('432.20'), Decimal('77.33')),
#  ('Niue', 2015, None, Decimal('98.00')),
#  ('Niue', 2016, None, Decimal('97.00')),
#  ('Niue', 2017, None, Decimal('97.00')),
#  ('Niue', 2018, None, Decimal('97.00')),
#  ('Niue', 2019, None, Decimal('97.00')),
#  ('Niue', 2020, None, Decimal('97.00')),
#  ('Northern Mariana Islands', 2015, Decimal('0.91'), Decimal('100.00')),
#  ('Northern Mariana Islands', 2016, Decimal('1.23'), Decimal('100.00')),
#  ('Northern Mariana Islands', 2017, Decimal('1.56'), Decimal('100.00')),
#  ('Northern Mariana Islands', 2018, Decimal('1.30'), Decimal('100.00')),
#  ('Northern Mariana Islands', 2019, Decimal('1.18'), Decimal('100.00')),
#  ('Northern Mariana Islands', 2020, None, Decimal('100.00')),
#  ('Oman', 2015, Decimal('78.71'), Decimal('86.00')),
#  ('Oman', 2016, Decimal('75.13'), Decimal('86.67')),
#  ('Oman', 2017, Decimal('80.86'), Decimal('86.67')),
#  ('Oman', 2018, Decimal('91.51'), Decimal('87.00')),
#  ('Oman', 2019, Decimal('88.06'), Decimal('87.67')),
#  ('Oman', 2020, Decimal('75.91'), Decimal('87.67')),
#  ('Pakistan', 2015, Decimal('270.56'), Decimal('90.00')),
#  ('Pakistan', 2016, Decimal('313.63'), Decimal('90.00')),
#  ('Pakistan', 2017, Decimal('339.21'), Decimal('90.33')),
#  ('Pakistan', 2018, Decimal('356.13'), Decimal('90.33')),
#  ('Pakistan', 2019, Decimal('320.91'), Decimal('90.33')),
#  ('Pakistan', 2020, Decimal('300.43'), Decimal('90.67')),
#  ('Palau', 2015, Decimal('0.28'), Decimal('100.00')),
#  ('Palau', 2016, Decimal('0.30'), Decimal('100.00')),
#  ('Palau', 2017, Decimal('0.29'), Decimal('100.00')),
#  ('Palau', 2018, Decimal('0.28'), Decimal('100.00')),
#  ('Palau', 2019, Decimal('0.28'), Decimal('100.00')),
#  ('Palau', 2020, Decimal('0.25'), Decimal('100.00')),
#  ('Panama', 2015, Decimal('54.09'), Decimal('91.67')),
#  ('Panama', 2016, Decimal('57.91'), Decimal('91.67')),
#  ('Panama', 2017, Decimal('62.20'), Decimal('92.33')),
#  ('Panama', 2018, Decimal('64.93'), Decimal('92.33')),
#  ('Panama', 2019, Decimal('66.98'), Decimal('92.67')),
#  ('Panama', 2020, Decimal('53.98'), Decimal('92.67')),
#  ('Papua New Guinea', 2015, Decimal('21.72'), Decimal('53.67')),
#  ('Papua New Guinea', 2016, Decimal('20.76'), Decimal('54.33')),
#  ('Papua New Guinea', 2017, Decimal('22.74'), Decimal('55.00')),
#  ('Papua New Guinea', 2018, Decimal('24.11'), Decimal('55.67')),
#  ('Papua New Guinea', 2019, Decimal('24.75'), Decimal('56.33')),
#  ('Papua New Guinea', 2020, Decimal('23.85'), Decimal('56.67')),
#  ('Paraguay', 2015, Decimal('36.21'), Decimal('96.33')),
#  ('Paraguay', 2016, Decimal('36.09'), Decimal('97.67')),
#  ('Paraguay', 2017, Decimal('39.00'), Decimal('99.33')),
#  ('Paraguay', 2018, Decimal('40.23'), Decimal('99.67')),
#  ('Paraguay', 2019, Decimal('37.93'), Decimal('99.67')),
#  ('Paraguay', 2020, Decimal('35.43'), Decimal('99.67')),
#  ('Peru', 2015, Decimal('189.81'), Decimal('86.00')),
#  ('Peru', 2016, Decimal('191.90'), Decimal('87.33')),
#  ('Peru', 2017, Decimal('211.01'), Decimal('87.67')),
#  ('Peru', 2018, Decimal('222.60'), Decimal('88.67')),
#  ('Peru', 2019, Decimal('228.32'), Decimal('89.33')),
#  ('Peru', 2020, Decimal('201.71'), Decimal('90.33')),
#  ('Philippines', 2015, Decimal('306.45'), Decimal('92.00')),
#  ('Philippines', 2016, Decimal('318.63'), Decimal('92.67')),
#  ('Philippines', 2017, Decimal('328.48'), Decimal('93.00')),
#  ('Philippines', 2018, Decimal('346.84'), Decimal('93.33')),
#  ('Philippines', 2019, Decimal('376.82'), Decimal('93.67')),
#  ('Philippines', 2020, Decimal('361.75'), Decimal('94.00')),
#  ('Puerto Rico', 2015, Decimal('103.38'), Decimal('99.00')),
#  ('Puerto Rico', 2016, Decimal('104.34'), Decimal('100.00')),
#  ('Puerto Rico', 2017, Decimal('103.45'), Decimal('100.00')),
#  ('Puerto Rico', 2018, Decimal('100.96'), Decimal('100.00')),
#  ('Puerto Rico', 2019, Decimal('105.13'), Decimal('100.00')),
#  ('Puerto Rico', 2020, Decimal('103.02'), Decimal('100.00')),
#  ('Qatar', 2015, Decimal('161.74'), Decimal('100.00')),
#  ('Qatar', 2016, Decimal('151.73'), Decimal('100.00')),
#  ('Qatar', 2017, Decimal('161.10'), Decimal('100.00')),
#  ('Qatar', 2018, Decimal('183.33'), Decimal('100.00')),
#  ('Qatar', 2019, Decimal('175.84'), Decimal('100.00')),
#  ('Qatar', 2020, Decimal('144.41'), Decimal('100.00')),
#  ('Republic of Korea', 2015, None, Decimal('99.00')),
#  ('Republic of Korea', 2016, None, Decimal('100.00')),
#  ('Republic of Korea', 2017, None, Decimal('100.00')),
#  ('Republic of Korea', 2018, None, Decimal('100.00')),
#  ('Republic of Korea', 2019, None, Decimal('100.00')),
#  ('Republic of Korea', 2020, None, Decimal('100.00')),
#  ('Réunion', 2015, None, Decimal('100.00')),
#  ('Réunion', 2016, None, Decimal('100.00')),
#  ('Réunion', 2017, None, Decimal('100.00')),
#  ('Réunion', 2018, None, Decimal('100.00')),
#  ('Réunion', 2019, None, Decimal('100.00')),
#  ('Réunion', 2020, None, Decimal('100.00')),
#  ('Rwanda', 2015, Decimal('8.54'), Decimal('63.00')),
#  ('Rwanda', 2016, Decimal('8.69'), Decimal('64.00')),
#  ('Rwanda', 2017, Decimal('9.25'), Decimal('65.00')),
#  ('Rwanda', 2018, Decimal('9.64'), Decimal('65.67')),
#  ('Rwanda', 2019, Decimal('10.36'), Decimal('66.33')),
#  ('Rwanda', 2020, Decimal('10.18'), Decimal('66.33')),
#  ('Saint Barthélemy', 2015, None, Decimal('100.00')),
#  ('Saint Barthélemy', 2016, None, Decimal('100.00')),
#  ('Saint Barthélemy', 2017, None, Decimal('100.00')),
#  ('Saint Barthélemy', 2018, None, Decimal('100.00')),
#  ('Saint Barthélemy', 2019, None, Decimal('100.00')),
#  ('Saint Barthélemy', 2020, None, Decimal('100.00')),
#  ('Saint Helena', 2015, None, Decimal('99.00')),
#  ('Saint Helena', 2016, None, Decimal('99.00')),
#  ('Saint Helena', 2017, None, Decimal('99.00')),
#  ('Saint Helena', 2018, None, Decimal('99.00')),
#  ('Saint Helena', 2019, None, Decimal('99.00')),
#  ('Saint Helena', 2020, None, Decimal('99.00')),
#  ('Saint Kitts and Nevis', 2015, None, Decimal('99.00')),
#  ('Saint Kitts and Nevis', 2016, None, Decimal('99.00')),
#  ('Saint Kitts and Nevis', 2017, None, Decimal('99.00')),
#  ('Saint Lucia', 2015, None, Decimal('96.00')),
#  ('Saint Lucia', 2016, None, Decimal('96.33')),
#  ('Saint Lucia', 2017, None, Decimal('96.33')),
#  ('Saint Lucia', 2018, None, Decimal('97.00')),
#  ('Saint Lucia', 2019, None, Decimal('97.00')),
#  ('Saint Lucia', 2020, None, Decimal('97.00')),
#  ('Saint Martin (French Part)', 2015, None, Decimal('100.00')),
#  ('Saint Martin (French Part)', 2016, None, Decimal('100.00')),
#  ('Saint Martin (French Part)', 2017, None, Decimal('100.00')),
#  ('Saint Martin (French Part)', 2018, None, Decimal('100.00')),
#  ('Saint Martin (French Part)', 2019, None, Decimal('100.00')),
#  ('Saint Martin (French Part)', 2020, None, Decimal('100.00')),
#  ('Saint Pierre and Miquelon', 2015, None, Decimal('91.00')),
#  ('Saint Pierre and Miquelon', 2016, None, Decimal('91.00')),
#  ('Saint Pierre and Miquelon', 2017, None, Decimal('91.00')),
#  ('Saint Pierre and Miquelon', 2018, None, Decimal('91.00')),
#  ('Saint Pierre and Miquelon', 2019, None, Decimal('91.00')),
#  ('Saint Pierre and Miquelon', 2020, None, Decimal('91.00')),
#  ('Saint Vincent and the Grenadines', 2015, None, Decimal('95.00')),
#  ('Saint Vincent and the Grenadines', 2016, None, Decimal('95.00')),
#  ('Saint Vincent and the Grenadines', 2017, None, Decimal('95.00')),
#  ('Saint Vincent and the Grenadines', 2018, None, Decimal('95.00')),
#  ('Samoa', 2015, Decimal('0.82'), Decimal('91.00')),
#  ('Samoa', 2016, Decimal('0.84'), Decimal('92.00')),
#  ('Samoa', 2017, Decimal('0.88'), Decimal('92.00')),
#  ('Samoa', 2018, Decimal('0.88'), Decimal('92.00')),
#  ('Samoa', 2019, Decimal('0.91'), Decimal('92.00')),
#  ('Samoa', 2020, Decimal('0.87'), Decimal('92.00')),
#  ('Sao Tome and Principe', 2015, Decimal('0.32'), Decimal('76.00')),
#  ('Sao Tome and Principe', 2016, Decimal('0.35'), Decimal('76.67')),
#  ('Sao Tome and Principe', 2017, Decimal('0.38'), Decimal('77.00')),
#  ('Sao Tome and Principe', 2018, Decimal('0.41'), Decimal('77.00')),
#  ('Sao Tome and Principe', 2019, Decimal('0.43'), Decimal('77.33')),
#  ('Sao Tome and Principe', 2020, Decimal('0.47'), Decimal('77.33')),
#  ('Saudi Arabia', 2015, Decimal('654.27'), Decimal('100.00')),
#  ('Saudi Arabia', 2016, Decimal('644.94'), Decimal('100.00')),
#  ('Saudi Arabia', 2017, Decimal('688.59'), Decimal('100.00')),
#  ('Saudi Arabia', 2018, Decimal('816.58'), Decimal('100.00')),
#  ('Saudi Arabia', 2019, Decimal('803.62'), Decimal('100.00')),
#  ('Saudi Arabia', 2020, Decimal('703.37'), Decimal('100.00')),
#  ('Senegal', 2015, Decimal('17.77'), Decimal('79.67')),
#  ('Senegal', 2016, Decimal('19.04'), Decimal('80.67')),
#  ('Senegal', 2017, Decimal('21.00'), Decimal('81.67')),
#  ('Senegal', 2018, Decimal('23.12'), Decimal('82.67')),
#  ('Senegal', 2019, Decimal('23.40'), Decimal('84.00')),
#  ('Senegal', 2020, Decimal('24.49'), Decimal('85.00')),
#  ('Seychelles', 2015, Decimal('1.42'), Decimal('96.00')),
#  ('Seychelles', 2016, Decimal('1.49'), Decimal('96.00')),
#  ('Seychelles', 2017, Decimal('1.57'), Decimal('96.00')),
#  ('Seychelles', 2018, Decimal('1.64'), Decimal('96.00')),
#  ('Seychelles', 2019, Decimal('1.68'), Decimal('97.00')),
#  ('Sierra Leone', 2015, Decimal('4.22'), Decimal('60.00')),
#  ('Sierra Leone', 2016, Decimal('3.67'), Decimal('60.67')),
#  ('Sierra Leone', 2017, Decimal('3.72'), Decimal('61.67')),
#  ('Sierra Leone', 2018, Decimal('4.09'), Decimal('62.67')),
#  ('Sierra Leone', 2019, Decimal('4.08'), Decimal('64.00')),
#  ('Sierra Leone', 2020, Decimal('4.06'), Decimal('65.00')),
#  ('Singapore', 2015, Decimal('308.00'), Decimal('100.00')),
#  ('Singapore', 2016, Decimal('318.83'), Decimal('100.00')),
#  ('Singapore', 2017, Decimal('343.19'), Decimal('100.00')),
#  ('Singapore', 2018, Decimal('377.00'), Decimal('100.00')),
#  ('Singapore', 2019, Decimal('375.47'), Decimal('100.00')),
#  ('Singapore', 2020, Decimal('345.30'), Decimal('100.00')),
#  ('Sint Maarten (Dutch part)', 2015, Decimal('1.25'), Decimal('95.00')),
#  ('Sint Maarten (Dutch part)', 2016, Decimal('1.26'), Decimal('95.00')),
#  ('Sint Maarten (Dutch part)', 2017, Decimal('1.19'), Decimal('95.00')),
#  ('Solomon Islands', 2015, Decimal('1.31'), Decimal('74.33')),
#  ('Solomon Islands', 2016, Decimal('1.38'), Decimal('74.00')),
#  ('Solomon Islands', 2017, Decimal('1.47'), Decimal('73.33')),
#  ('Solomon Islands', 2018, Decimal('1.62'), Decimal('72.33')),
#  ('Solomon Islands', 2019, Decimal('1.62'), Decimal('72.33')),
#  ('Solomon Islands', 2020, Decimal('1.54'), Decimal('72.33')),
#  ('Somalia', 2015, Decimal('5.33'), Decimal('50.67')),
#  ('Somalia', 2016, Decimal('5.53'), Decimal('52.00')),
#  ('Somalia', 2017, Decimal('5.61'), Decimal('53.33')),
#  ('Somalia', 2018, Decimal('5.86'), Decimal('54.67')),
#  ('Somalia', 2019, Decimal('6.49'), Decimal('56.33')),
#  ('Somalia', 2020, Decimal('6.88'), Decimal('57.33')),
#  ('South Africa', 2015, Decimal('346.71'), Decimal('90.00')),
#  ('South Africa', 2016, Decimal('323.59'), Decimal('90.33')),
#  ('South Africa', 2017, Decimal('381.45'), Decimal('91.00')),
#  ('South Africa', 2018, Decimal('404.16'), Decimal('91.33')),
#  ('South Africa', 2019, Decimal('388.53'), Decimal('91.67')),
#  ('South Africa', 2020, Decimal('337.62'), Decimal('92.00')),
#  ('South Sudan', 2015, Decimal('12.00'), Decimal('46.33')),
#  ('South Sudan', 2016, None, Decimal('46.67')),
#  ('South Sudan', 2017, None, Decimal('47.00')),
#  ('South Sudan', 2018, None, Decimal('47.67')),
#  ('South Sudan', 2019, None, Decimal('48.33')),
#  ('South Sudan', 2020, None, Decimal('48.33')),
#  ('Sri Lanka', 2015, Decimal('85.14'), Decimal('92.00')),
#  ('Sri Lanka', 2016, Decimal('88.01'), Decimal('93.00')),
#  ('Sri Lanka', 2017, Decimal('94.38'), Decimal('93.67')),
#  ('Sri Lanka', 2018, Decimal('94.49'), Decimal('94.33')),
#  ('Sri Lanka', 2019, Decimal('89.01'), Decimal('94.33')),
#  ('Sri Lanka', 2020, Decimal('85.35'), Decimal('94.33')),
#  ('State of Palestine', 2015, None, Decimal('96.00')),
#  ('State of Palestine', 2016, None, Decimal('96.67')),
#  ('State of Palestine', 2017, None, Decimal('97.00')),
#  ('State of Palestine', 2018, None, Decimal('97.00')),
#  ('State of Palestine', 2019, None, Decimal('97.67')),
#  ('State of Palestine', 2020, None, Decimal('98.33')),
#  ('Sudan', 2015, Decimal('84.99'), Decimal('61.33')),
#  ('Sudan', 2016, Decimal('102.94'), Decimal('62.33')),
#  ('Sudan', 2017, Decimal('129.72'), Decimal('62.33')),
#  ('Sudan', 2018, Decimal('32.33'), Decimal('62.33')),
#  ('Sudan', 2019, Decimal('32.34'), Decimal('62.33')),
#  ('Sudan', 2020, Decimal('27.03'), Decimal('62.33')),
#  ('Suriname', 2015, Decimal('5.13'), Decimal('95.00')),
#  ('Suriname', 2016, Decimal('3.32'), Decimal('95.33')),
#  ('Suriname', 2017, Decimal('3.59'), Decimal('96.33')),
#  ('Suriname', 2018, Decimal('4.00'), Decimal('96.67')),
#  ('Suriname', 2019, Decimal('4.02'), Decimal('97.33')),
#  ('Suriname', 2020, Decimal('2.91'), Decimal('98.00')),
#  ('Syrian Arab Republic', 2015, Decimal('16.47'), Decimal('93.33')),
#  ('Syrian Arab Republic', 2016, Decimal('12.60'), Decimal('93.67')),
#  ('Syrian Arab Republic', 2017, Decimal('16.37'), Decimal('93.67')),
#  ('Syrian Arab Republic', 2018, Decimal('21.35'), Decimal('93.67')),
#  ('Syrian Arab Republic', 2019, Decimal('22.44'), Decimal('93.67')),
#  ('Syrian Arab Republic', 2020, Decimal('11.08'), Decimal('93.67')),
#  ('Tajikistan', 2015, Decimal('8.27'), Decimal('80.33')),
#  ('Tajikistan', 2016, Decimal('6.99'), Decimal('81.33')),
#  ('Tajikistan', 2017, Decimal('7.54'), Decimal('82.33')),
#  ('Tajikistan', 2018, Decimal('7.77'), Decimal('83.33')),
#  ('Tajikistan', 2019, Decimal('8.30'), Decimal('85.00')),
#  ('Tajikistan', 2020, Decimal('8.13'), Decimal('85.00')),
#  ('Thailand', 2015, Decimal('401.30'), Decimal('99.33')),
#  ('Thailand', 2016, Decimal('413.37'), Decimal('99.33')),
#  ('Thailand', 2017, Decimal('456.36'), Decimal('100.00')),
#  ('Thailand', 2018, Decimal('506.75'), Decimal('100.00')),
#  ('Thailand', 2019, Decimal('544.08'), Decimal('100.00')),
#  ('Thailand', 2020, Decimal('499.68'), Decimal('100.00')),
#  ('Timor-Leste', 2015, Decimal('1.59'), Decimal('78.00')),
#  ('Timor-Leste', 2016, Decimal('1.65'), Decimal('80.67')),
#  ('Timor-Leste', 2017, Decimal('1.60'), Decimal('82.33')),
#  ('Timor-Leste', 2018, Decimal('1.56'), Decimal('84.33')),
#  ('Timor-Leste', 2019, Decimal('2.03'), Decimal('86.00')),
#  ('Timor-Leste', 2020, Decimal('2.16'), Decimal('87.00')),
#  ('Togo', 2015, Decimal('4.18'), Decimal('66.33')),
#  ('Togo', 2016, Decimal('6.03'), Decimal('67.33')),
#  ('Togo', 2017, Decimal('6.40'), Decimal('68.33')),
#  ('Togo', 2018, Decimal('7.11'), Decimal('69.33')),
#  ('Togo', 2019, Decimal('7.22'), Decimal('70.33')),
#  ('Togo', 2020, Decimal('7.57'), Decimal('70.67')),
#  ('Tokelau', 2015, None, Decimal('99.00')),
#  ('Tokelau', 2016, None, Decimal('100.00')),
#  ('Tokelau', 2017, None, Decimal('100.00')),
#  ('Tokelau', 2018, None, Decimal('100.00')),
#  ('Tokelau', 2019, None, Decimal('100.00')),
#  ('Tokelau', 2020, None, Decimal('100.00')),
#  ('Tonga', 2015, Decimal('0.44'), Decimal('98.67')),
#  ('Tonga', 2016, Decimal('0.42'), Decimal('98.67')),
#  ('Tonga', 2017, Decimal('0.46'), Decimal('98.67')),
#  ('Tonga', 2018, Decimal('0.49'), Decimal('98.67')),
#  ('Tonga', 2019, Decimal('0.51'), Decimal('98.67')),
#  ('Tonga', 2020, Decimal('0.48'), Decimal('99.00')),
#  ('Trinidad and Tobago', 2015, Decimal('26.85'), Decimal('98.00')),
#  ('Trinidad and Tobago', 2016, Decimal('23.50'), Decimal('99.00')),
#  ('Trinidad and Tobago', 2017, Decimal('23.80'), Decimal('99.00')),
#  ('Trinidad and Tobago', 2018, Decimal('24.32'), Decimal('99.00')),
#  ('Trinidad and Tobago', 2019, Decimal('23.85'), Decimal('99.00')),
#  ('Trinidad and Tobago', 2020, Decimal('21.06'), Decimal('99.00')),
#  ('Tunisia', 2015, Decimal('45.78'), Decimal('93.33')),
#  ('Tunisia', 2016, Decimal('44.36'), Decimal('93.67')),
#  ('Tunisia', 2017, Decimal('42.16'), Decimal('94.67')),
#  ('Tunisia', 2018, Decimal('42.69'), Decimal('95.67')),
#  ('Tunisia', 2019, Decimal('41.91'), Decimal('96.00')),
#  ('Tunisia', 2020, Decimal('42.54'), Decimal('97.00')),
#  ('Türkiye', 2015, None, Decimal('95.67')),
#  ('Türkiye', 2016, None, Decimal('96.00')),
#  ('Türkiye', 2017, None, Decimal('96.33')),
#  ('Türkiye', 2018, None, Decimal('96.33')),
#  ('Türkiye', 2019, None, Decimal('96.67')),
#  ('Türkiye', 2020, None, Decimal('96.67')),
#  ('Turkmenistan', 2015, Decimal('35.80'), Decimal('97.67')),
#  ('Turkmenistan', 2016, Decimal('36.17'), Decimal('98.00')),
#  ('Turkmenistan', 2017, Decimal('37.93'), Decimal('98.67')),
#  ('Turkmenistan', 2018, Decimal('40.77'), Decimal('99.33')),
#  ('Turkmenistan', 2019, Decimal('45.23'), Decimal('100.00')),
#  ('Turkmenistan', 2020, None, Decimal('100.00')),
#  ('Turks and Caicos Islands', 2015, Decimal('0.94'), Decimal('94.00')),
#  ('Turks and Caicos Islands', 2016, Decimal('1.03'), Decimal('94.00')),
#  ('Turks and Caicos Islands', 2017, Decimal('1.02'), Decimal('94.00')),
#  ('Turks and Caicos Islands', 2018, Decimal('1.11'), Decimal('94.00')),
#  ('Tuvalu', 2015, Decimal('0.04'), Decimal('100.00')),
#  ('Tuvalu', 2016, Decimal('0.04'), Decimal('100.00')),
#  ('Tuvalu', 2017, Decimal('0.05'), Decimal('100.00')),
#  ('Tuvalu', 2018, Decimal('0.05'), Decimal('100.00')),
#  ('Tuvalu', 2019, Decimal('0.05'), Decimal('100.00')),
#  ('Tuvalu', 2020, Decimal('0.06'), Decimal('100.00')),
#  ('Uganda', 2015, Decimal('32.39'), Decimal('55.00')),
#  ('Uganda', 2016, Decimal('29.20'), Decimal('55.67')),
#  ('Uganda', 2017, Decimal('30.74'), Decimal('57.00')),
#  ('Uganda', 2018, Decimal('32.93'), Decimal('58.67')),
#  ('Uganda', 2019, Decimal('35.35'), Decimal('59.33')),
#  ('Uganda', 2020, Decimal('37.60'), Decimal('61.00')),
#  ('United Arab Emirates', 2015, Decimal('370.28'), Decimal('100.00')),
#  ('United Arab Emirates', 2016, Decimal('369.26'), Decimal('100.00')),
#  ('United Arab Emirates', 2017, Decimal('390.52'), Decimal('100.00')),
#  ('United Arab Emirates', 2018, Decimal('427.05'), Decimal('100.00')),
#  ('United Arab Emirates', 2019, Decimal('417.99'), Decimal('100.00')),
#  ('United Arab Emirates', 2020, Decimal('349.47'), Decimal('100.00')),
#  ('United Republic of Tanzania', 2015, None, Decimal('58.33')),
#  ('United Republic of Tanzania', 2016, None, Decimal('60.00')),
#  ('United Republic of Tanzania', 2017, None, Decimal('61.67')),
#  ('United Republic of Tanzania', 2018, None, Decimal('63.33')),
#  ('United Republic of Tanzania', 2019, None, Decimal('64.67')),
#  ('United Republic of Tanzania', 2020, None, Decimal('65.00')),
#  ('United States of America', 2015, None, Decimal('99.00')),
#  ('United States of America', 2016, None, Decimal('99.33')),
#  ('United States of America', 2017, None, Decimal('99.67')),
#  ('United States of America', 2018, None, Decimal('99.67')),
#  ('United States of America', 2019, None, Decimal('99.67')),
#  ('United States of America', 2020, None, Decimal('100.00')),
#  ('United States Virgin Islands', 2015, None, Decimal('99.00')),
#  ('United States Virgin Islands', 2016, None, Decimal('99.00')),
#  ('United States Virgin Islands', 2017, None, Decimal('99.00')),
#  ('United States Virgin Islands', 2018, None, Decimal('99.00')),
#  ('United States Virgin Islands', 2019, None, Decimal('99.00')),
#  ('United States Virgin Islands', 2020, None, Decimal('99.00')),
#  ('Uruguay', 2015, Decimal('53.27'), Decimal('96.67')),
#  ('Uruguay', 2016, Decimal('57.24'), Decimal('97.33')),
#  ('Uruguay', 2017, Decimal('64.23'), Decimal('98.00')),
#  ('Uruguay', 2018, Decimal('64.52'), Decimal('98.00')),
#  ('Uruguay', 2019, Decimal('61.23'), Decimal('98.00')),
#  ('Uruguay', 2020, Decimal('53.56'), Decimal('98.00')),
#  ...]

# %% [markdown]
# ### Task 3
#
# Using the query created in Task 2, filter the results to display records where:
#
# 1. The year = 2020.
# 2. The GDP is above the global average.
# 3. Less than 90% of the country's population have access to managed drinking water services.
#
# Hint: Keep in mind that we determined the GDP above the global average in Task 1.

# %%
# %%sql
#
# SELECT
# 	b.Country_name,
#     b.Time_period,
#     e.Est_gdp_in_billions,
#     b.Pct_managed_drinking_water_services
# FROM
# 	united_nations.basic_services b
# INNER JOIN
#     united_nations.economic_indicators e
#     ON
# 		b.Country_name = e.Country_name
# 	AND
# 		b.Time_period = e.Time_period
# WHERE
# 	b.Time_period = 2020
# AND
# 	b.Pct_managed_drinking_water_services < 90
# AND
# 	e.Est_gdp_in_billions > (SELECT
# 								AVG(Est_gdp_in_billions)
# 							FROM
# 								united_nations.Economic_Indicators
# 							WHERE
# 								Time_period = 2020
# 							);
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 1 rows affected.
# [('Nigeria', 2020, Decimal('432.20'), Decimal('77.33'))]

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### Task 1

# %%
# %%sql
#
# SELECT
#     AVG(Est_gdp_in_billions)
# FROM
#     Economic_Indicators
# WHERE
#     Time_period = 2020;

# %% [markdown]
# ### Task 2

# %%
# %%sql
#
# SELECT
#     econ.Country_name,
#     econ.Time_period,
#     econ.Est_gdp_in_billions,
#     service.Pct_managed_drinking_water_services
# FROM
#     Economic_Indicators AS econ
# INNER JOIN
#     Basic_Services AS service
# ON
#     econ.Country_name = service.Country_name
#     AND econ.Time_period = service.Time_period
# LIMIT 10;

# %% [markdown]
# ### Task 3

# %%
# %%sql
#
# SELECT
#     econ.Country_name,
#     econ.Time_period,
#     econ.Est_gdp_in_billions,
#     service.Pct_managed_drinking_water_services
# FROM
#     Economic_Indicators AS econ
# INNER JOIN
#     Basic_Services AS service
# ON
#     econ.Country_name = service.Country_name
#     AND econ.Time_period = service.Time_period
# WHERE
#     econ.time_period = 2020
#     AND service.Pct_managed_drinking_water_services < 90
#     AND econ.Est_gdp_in_billions > (SELECT
#                                         AVG(Est_gdp_in_billions)
#                                     FROM
#                                         Economic_Indicators
#                                     WHERE
#                                         Time_period = 2020);

# %% [markdown]
# ## Summary

# %% [markdown]
# This layered query first calculates the average GDP and then uses that value to filter out countries, along with all of the other criteria.
# Nigeria is the only country that satisfies this criteria. While its GDP might be above average, the low access to water is linked to policies that are not aligned with SDG 6, bad governance, infrastructure, quality, and supply, according to the World Bank.
# Finally, note that these queries quickly become complex when we use JOINs, subqueries, filters, and calculations together. The code is hard to read now and will be even harder to read for someone else who might work on this later. So we need to be mindful of this as we create these complex queries.

# %% [markdown]
# #
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/refs/heads/master/ALX_banners/ALX_Navy.png"  style="width:100px"  ;/>
# </div>
