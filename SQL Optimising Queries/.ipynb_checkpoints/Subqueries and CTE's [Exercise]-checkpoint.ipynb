# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img
#  src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/alx-courses/aice/assets/Content_page_banner_blue_dots.png"
#  alt="ALX Content Header"
#  class="full-width-image"
# />
# </div>

# %% [markdown]
# # Subqueries and CTEs

# %% [markdown]
# In this exercise, we will apply subqueries and CTEs in different parts of a query and for different use cases. Ensure that you have downloaded the database file, Northwind.db.

# %% [markdown]
# ## Learning objectives
#
# By the end of this train, you should:
# - Know how to use CTEs to simplify subqueries.
# - Understand when to use subqueries and when to use CTEs by comparing their performance and readability.

# %% [markdown]
# First, let's load our sample database:

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook.
# %load_ext sql

# %%
# Load the Northwind database stored in your local machine. 
# Make sure the file is saved in the same folder as this notebook.
# %sql sqlite:///Northwind.db
# Out:
# 'Connected: @Northwind.db'

# %%
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'

# %% [markdown]
# Here is a view of all of our tables in the database:

# %% [markdown]
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/Northwind_ERD.png"  style="width:500px";/>
# <br>
# <br>
#     <em>Figure 1: Northwind ERD</em>
# </div>

# %% [markdown]
# ## Exercise
#
# Run the necessary queries that will provide us with the following information. Compare your queries with the solutions at the end of this notebook.

# %% [markdown]
# ### Exercise 1
#
# Retrieve product details from products that have been ordered by customers from the UK.

# %%
# %%sql
#
#
# -- SUBQUERY SOLUTION
#
# SELECT
#     o.*
# FROM
#     orders o
# WHERE
#     o.CustomerID IN(
#         SELECT
#             c.CustomerID
#         FROM
#             customers c
#         WHERE
#             c.Country = "UK"
#         GROUP BY
#             c.CustomerID
#         ORDER BY COUNT(*) DESC
#     )
# LIMIT 10;
#
#
# -- CTE SOLUTION
#
# WITH uk_customers AS (
#     SELECT
#         c.CustomerID
#     FROM
#         customers c
#     WHERE
#         c.Country = "UK"
#     GROUP BY
#         c.CustomerID
#     ORDER BY COUNT(*) DESC
# )
#
# SELECT
#     o.*
# FROM
#     orders o
# JOIN
#     uk_customers u
# ON
#     o.CustomerID = u.CustomerID
# LIMIT 10;
# Out:
#  * sqlite:///Northwind.db
# Done.
# Done.
# [(10289, 'BSBEV', 7, '2016-08-26', '2016-09-23', '2016-08-28', 3, 19.75, 'B-s Beverages', 'Fauntleroy Circus', 'London', 'British Isles', 'EC2 5NT', 'UK'),
#  (10315, 'ISLAT', 4, '2016-09-26', '2016-10-24', '2016-10-03', 2, 21, 'Island Trading', 'Garden House Crowther Way', 'Cowes', 'British Isles', 'PO31 7PJ', 'UK'),
#  (10318, 'ISLAT', 8, '2016-10-01', '2016-10-29', '2016-10-04', 2, 16.5, 'Island Trading', 'Garden House Crowther Way', 'Cowes', 'British Isles', 'PO31 7PJ', 'UK'),
#  (10321, 'ISLAT', 3, '2016-10-03', '2016-10-31', '2016-10-11', 2, 12.5, 'Island Trading', 'Garden House Crowther Way', 'Cowes', 'British Isles', 'PO31 7PJ', 'UK'),
#  (10355, 'AROUT', 6, '2016-11-15', '2016-12-13', '2016-11-20', 1, 22.5, 'Around the Horn', 'Brook Farm Stratford St. Mary', 'Colchester', 'British Isles', 'CO7 6JX', 'UK'),
#  (10359, 'SEVES', 5, '2016-11-21', '2016-12-19', '2016-11-26', 3, 61.5, 'Seven Seas Imports', '90 Wadhurst Rd.', 'London', 'British Isles', 'OX15 4NB', 'UK'),
#  (10364, 'EASTC', 1, '2016-11-26', '2017-01-07', '2016-12-04', 1, 18.75, 'Eastern Connection', '35 King George', 'London', 'British Isles', 'WX3 6FW', 'UK'),
#  (10377, 'SEVES', 1, '2016-12-09', '2017-01-06', '2016-12-13', 3, 20, 'Seven Seas Imports', '90 Wadhurst Rd.', 'London', 'British Isles', 'OX15 4NB', 'UK'),
#  (10383, 'AROUT', 8, '2016-12-16', '2017-01-13', '2016-12-18', 3, 23.75, 'Around the Horn', 'Brook Farm Stratford St. Mary', 'Colchester', 'British Isles', 'CO7 6JX', 'UK'),
#  (10388, 'SEVES', 2, '2016-12-19', '2017-01-16', '2016-12-20', 1, 28.75, 'Seven Seas Imports', '90 Wadhurst Rd.', 'London', 'British Isles', 'OX15 4NB', 'UK')]

# %% [markdown]
# ### Exercise 2
#
#
# Find out the names of customers who have ordered products of more than the average order value.

# %%
# %%sql
#
# WITH Avg_orders AS (
#     SELECT
#         AVG(od.UnitPrice * od.Quantity) AS avg_value
#     FROM "Order Details" AS od
# )
#
# SELECT DISTINCT
#     c.CompanyName
# FROM
#     customers AS c
# JOIN
#     orders AS o
# ON
#     c.CustomerID = o.CustomerID
# JOIN
#     "Order Details" AS od
# ON
#     o.OrderID = od.OrderID
# WHERE
#     (od.UnitPrice * od.Quantity) > (SELECT avg_value FROM Avg_orders);
# Out:
#  * sqlite:///Northwind.db
# Done.
# [('Toms Spezialitäten',),
#  ('Hanari Carnes',),
#  ('Suprêmes délices',),
#  ('Richter Supermarkt',),
#  ('HILARION-Abastos',),
#  ('Ernst Handel',),
#  ('Ottilies Käseladen',),
#  ('Blondesddsl père et fils',),
#  ('Frankenversand',),
#  ('GROSELLA-Restaurante',),
#  ('Wartian Herkku',),
#  ('QUICK-Stop',),
#  ('LILA-Supermercado',),
#  ('Comércio Mineiro',),
#  ('Tradição Hipermercados',),
#  ('Hungry Owl All-Night Grocers',),
#  ('Old World Delicatessen',),
#  ('Die Wandernde Kuh',),
#  ('Rattlesnake Canyon Grocery',),
#  ('Save-a-lot Markets',),
#  ('Königlich Essen',),
#  ('Folk och fä HB',),
#  ('Split Rail Beer & Ale',),
#  ('Mère Paillarde',),
#  ("Bon app'",),
#  ('Lehmanns Marktstand',),
#  ('White Clover Markets',),
#  ('Piccolo und mehr',),
#  ('Seven Seas Imports',),
#  ('Eastern Connection',),
#  ('Chop-suey Chinese',),
#  ('Queen Cozinha',),
#  ('Berglunds snabbköp',),
#  ('Bottom-Dollar Markets',),
#  ('Princesa Isabel Vinhos',),
#  ('Magazzini Alimentari Riuniti',),
#  ('Folies gourmandes',),
#  ("La maison d'Asie",),
#  ('Simons bistro',),
#  ('Wellington Importadora',),
#  ('Que Delícia',),
#  ('Gourmet Lanchonetes',),
#  ('Victuailles en stock',),
#  ('Furia Bacalhau e Frutos do Mar',),
#  ('Vaffeljernet',),
#  ('Ricardo Adocicados',),
#  ('Tortuga Restaurante',),
#  ('Antonio Moreno Taquería',),
#  ('Around the Horn',),
#  ('Morgenstern Gesundkost',),
#  ('Great Lakes Food Market',),
#  ('The Cracker Box',),
#  ('Godos Cocina Típica',),
#  ('LINO-Delicateses',),
#  ('Maison Dewey',),
#  ('Familia Arquibaldo',),
#  ('Hungry Coyote Import Store',),
#  ('Lonesome Pine Restaurant',),
#  ('Alfreds Futterkiste',),
#  ("Let's Stop N Shop",),
#  ('Reggiani Caseifici',),
#  ('Bólido Comidas preparadas',),
#  ('The Big Cheese',),
#  ('Island Trading',),
#  ('Santé Gourmet',),
#  ('Spécialités du monde',),
#  ('France restauration',),
#  ('Océano Atlántico Ltda.',),
#  ('Pericles Comidas clásicas',),
#  ("B's Beverages",),
#  ('Drachenblut Delikatessen',),
#  ('Romero y tomillo',),
#  ('Paris spécialités',),
#  ('Lazy K Kountry Store',),
#  ('Ana Trujillo Emparedados y helados',),
#  ('Franchi S.p.A.',),
#  ('Blauer See Delikatessen',),
#  ("Trail's Head Gourmet Provisioners",),
#  ('Centro comercial Moctezuma',),
#  ('Cactus Comidas para llevar',),
#  ('Vins et alcools Chevalier',),
#  ('FISSA Fabrica Inter. Salchichas S.A.',),
#  ('Wilman Kala',),
#  ('Du monde entier',),
#  ('North/South',),
#  ('IT',),
#  ("La corne d'abondance",),
#  ('Wolski  Zajazd',),
#  ('Rancho grande',),
#  ('Consolidated Holdings',),
#  ('Laughing Bacchus Wine Cellars',),
#  ('Galería del gastrónomo',)]

# %% [markdown]
# ### Exercise 3
#
#
# Write a CTE to find the most ordered product by each customer.

# %%
# %%sql
#
# WITH most_ordered_products AS (
#     SELECT customers.CustomerID, OrderDetails.ProductID, COUNT(*) AS order_count
#     FROM customers
#     JOIN orders ON customers.CustomerID = orders.CustomerID
#     JOIN "Order Details" AS OrderDetails ON orders.OrderID = OrderDetails.OrderID
#     GROUP BY customers.CustomerID, OrderDetails.ProductID
# )
# SELECT customers.CompanyName, products.ProductName, max_order_count
# FROM (
#     SELECT CustomerID, MAX(order_count) AS max_order_count
#     FROM most_ordered_products
#     GROUP BY CustomerID
# ) AS max_order_count
# JOIN most_ordered_products ON max_order_count.CustomerID = most_ordered_products.CustomerID AND max_order_count.max_order_count = most_ordered_products.order_count
# JOIN customers ON most_ordered_products.CustomerID = customers.CustomerID
# JOIN products ON most_ordered_products.ProductID = products.ProductID;
# Out:
#  * sqlite:///Northwind.db
# Done.
# [('Alfreds Futterkiste', "Grandma's Boysenberry Spread", 79),
#  ('Alfreds Futterkiste', 'Wimmers gute Semmelknödel', 79),
#  ('Ana Trujillo Emparedados y helados', 'Ipoh Coffee', 111),
#  ('Antonio Moreno Taquería', 'Ravioli Angelo', 90),
#  ('Around the Horn', 'Perth Pasties', 89),
#  ('Around the Horn', 'Escargots de Bourgogne', 89),
#  ('Berglunds snabbköp', 'Camembert Pierrot', 99),
#  ('Blauer See Delikatessen', 'Louisiana Hot Spiced Okra', 94),
#  ('Blondesddsl père et fils', 'Rhönbräu Klosterbier', 101),
#  ('Bólido Comidas preparadas', "Chef Anton's Cajun Seasoning", 106),
#  ("Bon app'", 'Pavlova', 97),
#  ('Bottom-Dollar Markets', 'Chai', 108),
#  ("B's Beverages", "Chef Anton's Gumbo Mix", 118),
#  ("B's Beverages", 'Singaporean Hokkien Fried Mee', 118),
#  ("B's Beverages", 'Raclette Courdavault', 118),
#  ("B's Beverages", 'Wimmers gute Semmelknödel', 118),
#  ('Cactus Comidas para llevar', 'Chai', 94),
#  ('Centro comercial Moctezuma', "Gustaf's Knäckebröd", 96),
#  ('Centro comercial Moctezuma', 'Mozzarella di Giovanni', 96),
#  ('Chop-suey Chinese', 'Nord-Ost Matjeshering', 103),
#  ('Comércio Mineiro', "Chef Anton's Gumbo Mix", 101),
#  ('Comércio Mineiro', 'Camembert Pierrot', 101),
#  ('Consolidated Holdings', 'Chocolade', 101),
#  ('Drachenblut Delikatessen', 'Konbu', 96),
#  ('Du monde entier', 'NuNuCa Nuß-Nougat-Creme', 87),
#  ('Eastern Connection', 'Tarte au sucre', 92),
#  ('Ernst Handel', 'Aniseed Syrup', 94),
#  ('Ernst Handel', 'Ravioli Angelo', 94),
#  ('Familia Arquibaldo', 'Gnocchi di nonna Alice', 99),
#  ('FISSA Fabrica Inter. Salchichas S.A.', 'Tofu', 97),
#  ('Folies gourmandes', 'Scottish Longbreads', 108),
#  ('Folk och fä HB', 'Pâté chinois', 98),
#  ('Frankenversand', 'Guaraná Fantástica', 91),
#  ('Frankenversand', 'Sasquatch Ale', 91),
#  ('France restauration', 'Northwoods Cranberry Sauce', 106),
#  ('Franchi S.p.A.', 'Mishi Kobe Niku', 99),
#  ('Franchi S.p.A.', "Gustaf's Knäckebröd", 99),
#  ('Furia Bacalhau e Frutos do Mar', 'Ipoh Coffee', 86),
#  ('Galería del gastrónomo', 'Sasquatch Ale', 96),
#  ('Godos Cocina Típica', 'Chai', 93),
#  ('Godos Cocina Típica', 'Northwoods Cranberry Sauce', 93),
#  ('Gourmet Lanchonetes', 'Tourtière', 108),
#  ('Great Lakes Food Market', 'Chocolade', 97),
#  ('GROSELLA-Restaurante', 'Ipoh Coffee', 92),
#  ('Hanari Carnes', 'Chartreuse verte', 100),
#  ('HILARION-Abastos', 'Teatime Chocolate Biscuits', 100),
#  ('Hungry Coyote Import Store', 'Nord-Ost Matjeshering', 114),
#  ('Hungry Owl All-Night Grocers', 'Mascarpone Fabioli', 97),
#  ('Island Trading', 'Carnarvon Tigers', 97),
#  ('Island Trading', 'Ipoh Coffee', 97),
#  ('Island Trading', 'Spegesild', 97),
#  ('Königlich Essen', 'Pâté chinois', 100),
#  ("La corne d'abondance", 'Geitost', 89),
#  ("La corne d'abondance", 'Spegesild', 89),
#  ("La corne d'abondance", 'Pâté chinois', 89),
#  ("La corne d'abondance", 'Longlife Tofu', 89),
#  ("La maison d'Asie", 'Zaanse koeken', 95),
#  ('Laughing Bacchus Wine Cellars', 'Tunnbröd', 88),
#  ('Lazy K Kountry Store', 'Ikura', 101),
#  ('Lehmanns Marktstand', 'Nord-Ost Matjeshering', 86),
#  ('Lehmanns Marktstand', 'Mozzarella di Giovanni', 86),
#  ("Let's Stop N Shop", 'Gravad lax', 108),
#  ('LILA-Supermercado', 'Mozzarella di Giovanni', 106),
#  ('LINO-Delicateses', 'Aniseed Syrup', 91),
#  ('LINO-Delicateses', "Jack's New England Clam Chowder", 91),
#  ('Lonesome Pine Restaurant', 'Perth Pasties', 89),
#  ('Magazzini Alimentari Riuniti', 'Raclette Courdavault', 99),
#  ('Magazzini Alimentari Riuniti', 'Scottish Longbreads', 99),
#  ('Maison Dewey', 'Raclette Courdavault', 97),
#  ('Mère Paillarde', 'Longlife Tofu', 104),
#  ('Morgenstern Gesundkost', 'Outback Lager', 109),
#  ('North/South', 'Queso Cabrales', 93),
#  ('Océano Atlántico Ltda.', 'Mishi Kobe Niku', 83),
#  ('Old World Delicatessen', 'Gorgonzola Telino', 96),
#  ('Ottilies Käseladen', 'Longlife Tofu', 96),
#  ('Paris spécialités', 'Rhönbräu Klosterbier', 99),
#  ('Pericles Comidas clásicas', "Chef Anton's Gumbo Mix", 102),
#  ('Piccolo und mehr', 'Mascarpone Fabioli', 110),
#  ('Princesa Isabel Vinhos', "Chef Anton's Gumbo Mix", 108),
#  ('Que Delícia', 'Chartreuse verte', 91),
#  ('Queen Cozinha', 'Tunnbröd', 104),
#  ('QUICK-Stop', 'Boston Crab Meat', 96),
#  ('Rancho grande', "Sir Rodney's Scones", 108),
#  ('Rattlesnake Canyon Grocery', 'Guaraná Fantástica', 95),
#  ('Reggiani Caseifici', 'Genen Shouyu', 90),
#  ('Ricardo Adocicados', 'Teatime Chocolate Biscuits', 112),
#  ('Richter Supermarkt', 'Inlagd Sill', 96),
#  ('Richter Supermarkt', 'Laughing Lumberjack Lager', 96),
#  ('Richter Supermarkt', 'Lakkalikööri', 96),
#  ('Romero y tomillo', 'Sasquatch Ale', 98),
#  ('Santé Gourmet', 'Rössle Sauerkraut', 93),
#  ('Santé Gourmet', 'Perth Pasties', 93),
#  ('Save-a-lot Markets', 'Chang', 90),
#  ('Save-a-lot Markets', 'Gorgonzola Telino', 90),
#  ('Save-a-lot Markets', 'Perth Pasties', 90),
#  ('Save-a-lot Markets', 'Louisiana Fiery Hot Pepper Sauce', 90),
#  ('Seven Seas Imports', 'Chang', 95),
#  ('Simons bistro', 'Queso Cabrales', 98),
#  ('Simons bistro', 'Tunnbröd', 98),
#  ('Spécialités du monde', 'Aniseed Syrup', 104),
#  ('Split Rail Beer & Ale', 'Northwoods Cranberry Sauce', 96),
#  ('Suprêmes délices', 'Gumbär Gummibärchen', 95),
#  ('The Big Cheese', 'Geitost', 97),
#  ('The Big Cheese', 'Rhönbräu Klosterbier', 97),
#  ('The Cracker Box', 'Rogede sild', 100),
#  ('Toms Spezialitäten', 'Louisiana Hot Spiced Okra', 102),
#  ('Tortuga Restaurante', 'Tourtière', 104),
#  ('Tortuga Restaurante', "Sirop d'érable", 104),
#  ('Tortuga Restaurante', 'Vegie-spread', 104),
#  ('Tradição Hipermercados', 'Rössle Sauerkraut', 105),
#  ("Trail's Head Gourmet Provisioners", "Uncle Bob's Organic Dried Pears", 90),
#  ('Vaffeljernet', 'Sasquatch Ale', 101),
#  ('IT', 'Outback Lager', 100),
#  ('Victuailles en stock', 'Tunnbröd', 109),
#  ('Vins et alcools Chevalier', 'Spegesild', 87),
#  ('IT', 'Pavlova', 103),
#  ('Die Wandernde Kuh', "Sir Rodney's Marmalade", 96),
#  ('Wartian Herkku', 'Teatime Chocolate Biscuits', 94),
#  ('Wartian Herkku', 'Tourtière', 94),
#  ('Wellington Importadora', 'Northwoods Cranberry Sauce', 108),
#  ('White Clover Markets', "Sirop d'érable", 96),
#  ('Wilman Kala', 'Louisiana Hot Spiced Okra', 93),
#  ('Wolski  Zajazd', 'Lakkalikööri', 97)]

# %% [markdown]
# ### Exercise 4
#
# Using a CTE, list employees who have more than the average number of reports.

# %%
# %%sql
#
# WITH avg_reports AS (
#     SELECT AVG(report_count) AS average_count
#     FROM (
#         SELECT COUNT(*) AS report_count
#         FROM employees
#         JOIN employees AS reports ON employees.EmployeeID = reports.ReportsTo
#         GROUP BY employees.EmployeeID
#     ) AS report_counts
# )
# SELECT employees.*
# FROM employees
# JOIN employees AS reports ON employees.EmployeeID = reports.ReportsTo
# GROUP BY employees.EmployeeID
# HAVING COUNT(*) > (SELECT average_count FROM avg_reports);
# Out:
#  * sqlite:///Northwind.db
# Done.
# [(2, 'Fuller', 'Andrew', 'Vice President, Sales', 'Dr.', '1972-02-19', '2012-08-14', '908 W. Capital Way', 'Tacoma', 'North America', '98401', 'USA', '(206) 555-9482', '3457', b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x02\x00\x00d\x00d\x00\x00\xff\xec\x00\x11Ducky\x00\x01\x00\x04\x00\x00\x00P\x00\x00\xff\xee\x00&Adobe\x00d\xc0\ ... (35229 characters truncated) ... \xee\xbd\xe6\xbf>w\xed4o\xed\xc4\xd2\x1b\x9e\xb4=\xfd\xa7\xdb\xfcO\xf6O\xec\xfdi\xeah\xf5\x9a=8\xfe\xcd\xdf\xd7\xfb\xe2l\xdf\xf2k\xfe\xa7\xff\xd9\x00', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and  ... (150 characters truncated) ... es in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', None, 'http://accweb/emmployees/fuller.bmp')]

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### Exercise 1

# %% [markdown]
# SQL solution with a subquery:

# %%
# %%sql
#
# SELECT customers.*
# FROM customers
# WHERE customers.CustomerID IN (
#     SELECT orders.CustomerID
#     FROM orders
#     GROUP BY orders.CustomerID
#     ORDER BY COUNT(*) DESC
#     LIMIT 1
# );

# %% [markdown]
# SQL solution with a CTE:

# %%
# %%sql
#
# WITH most_orders AS (
#     SELECT orders.CustomerID
#     FROM orders
#     GROUP BY orders.CustomerID
#     ORDER BY COUNT(*) DESC
#     LIMIT 1
# )
# SELECT customers.*
# FROM customers
# JOIN most_orders
# ON customers.CustomerID = most_orders.CustomerID;

# %% [markdown]
# Both solutions will return the customer with the most orders. The subquery solution nests the logic inside the main query, which can become difficult to read for more complex queries. The CTE solution separates the logic into a different part of the query, which can be more readable, especially for more complex queries.

# %% [markdown]
# ### Exercise 2

# %%
# %%sql
#
# WITH avg_order_value AS (
#     SELECT AVG(OrderDetails.UnitPrice * OrderDetails.Quantity) AS average_value
#     FROM OrderDetails
# )
# SELECT DISTINCT customers.CompanyName
# FROM customers
# JOIN orders ON customers.CustomerID = orders.CustomerID
# JOIN OrderDetails ON orders.OrderID = OrderDetails.OrderID
# WHERE (OrderDetails.UnitPrice * OrderDetails.Quantity) > (SELECT average_value FROM avg_order_value);

# %% [markdown]
# ### Exercise 3

# %%
# %%sql
#
# WITH most_ordered_products AS (
#     SELECT customers.CustomerID, OrderDetails.ProductID, COUNT(*) AS order_count
#     FROM customers
#     JOIN orders ON customers.CustomerID = orders.CustomerID
#     JOIN OrderDetails ON orders.OrderID = OrderDetails.OrderID
#     GROUP BY customers.CustomerID, OrderDetails.ProductID
# )
# SELECT customers.CompanyName, products.ProductName, max_order_count
# FROM (
#     SELECT CustomerID, MAX(order_count) AS max_order_count
#     FROM most_ordered_products
#     GROUP BY CustomerID
# ) AS max_order_count
# JOIN most_ordered_products ON max_order_count.CustomerID = most_ordered_products.CustomerID AND max_order_count.max_order_count = most_ordered_products.order_count
# JOIN customers ON most_ordered_products.CustomerID = customers.CustomerID
# JOIN products ON most_ordered_products.ProductID = products.ProductID;

# %% [markdown]
# ### Exercise 4

# %%
# %%sql
#
# WITH avg_reports AS (
#     SELECT AVG(report_count) AS average_count
#     FROM (
#         SELECT COUNT(*) AS report_count
#         FROM employees
#         JOIN employees AS reports ON employees.EmployeeID = reports.ReportsTo
#         GROUP BY employees.EmployeeID
#     ) AS report_counts
# )
# SELECT employees.*
# FROM employees
# JOIN employees AS reports ON employees.EmployeeID = reports.ReportsTo
# GROUP BY employees.EmployeeID
# HAVING COUNT(*) > (SELECT average_count FROM avg_reports);

# %% [markdown]
# #
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/refs/heads/master/ALX_banners/ALX_Navy.png"  style="width:100px"  ;/>
# </div>
