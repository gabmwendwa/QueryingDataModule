# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img
#  src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/alx-courses/aice/assets/Content_page_banner_blue_dots.png"
#  alt="ALX Content Header"
#  class="full-width-image"
# />
# </div>

# %% [markdown]
# # Recreating the Access_to_Basic_Services dataset

# %% [markdown]
# In this notebook, we cover how ERDs help us understand database joins better. We also focus on the `LEFT JOIN` technique and highlight the importance of picking the right joining strategy, as incorrect joins can lead to inaccurate results.

# %% [markdown]
# > ⚠️ This notebook will not run on Google Colab because it cannot connect to a local database. Please make sure that this notebook is running on the same local machine as your MySQL Workbench installation and MySQL `united_nations` database.

# %% [markdown]
# ## Learning objectives
#
# By the end of this train, you will:
# - Understand how Entity-Relationship Diagrams can help us understand database joins better.
# - Understand the `LEFT JOIN` technique and how it is used to combine tables.
# - Know the importance of picking the right joining strategy and how incorrect joins can lead to inaccurate results.

# %% [markdown]
# ## Overview
#
# Entity-Relationship diagrams play a valuable role in determining the table relationships and join strategies within a database. They provide the means to make informed decisions about which tables to join and the appropriate method for doing so.
#
#
# Let’s recall our united_nations ERD which has three entities: Geographic_Location, Basic_Services, and Economic_Indicators.
#
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/Northwind_ERD.png" alt= "united_nations ERD" width="60%" height="60%">

# %% [markdown]
# One common joining technique involves selecting a central table that serves as the core of all relationships in the database and employing a `LEFT JOIN`.
# In our case, the `Geographic_Location` table would be the central table.
#
# With a `LEFT JOIN`, all records from the left table are returned, along with the corresponding matching records from the right table. In cases where there is no match, the result will include NULL values on the right side.

# %% [markdown]
# ## Connecting to our MySQL database
#
# We'll start by connecting to the `united_nations` database. To connect to the MySQL server, run the cells below.

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook. 
# If you get an error here, make sure that mysql and pymysql are installed correctly. 

# %load_ext sql

# %%
# Establish a connection to the local database using the '%sql' magic command.
# Replace 'password' with our connection password. 
# If you get an error here, please make sure the database name or password is correct.

# %sql mysql+pymysql://root:Innovator1@localhost:3306/united_nations
# Out:
# 'Connected: root@united_nations'

# %%
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'

# %% [markdown]
# We'll then use a simple `SELECT` query to fetch all records from the `Geographic_Location` table.

# %%
# %%sql
# SELECT
# 	*
# FROM
# 	united_nations.Geographic_Location as geo
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 5 rows affected.
# [('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00')),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200.00')),
#  ('Angola', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1246700.00')),
#  ('Anguilla', 'Caribbean', 'Latin America and the Caribbean', None)]

# %% [markdown]
# ## Exercise

# %% [markdown]
# ### 1. First `LEFT JOIN`
#
# Combine the `Geographic_Location` table with the `Economic_Indicators` table based on the `Country_name` column.

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     Geographic_Location g
# LEFT JOIN
#     Economic_Indicators e
# ON
#     g.Country_name = e.Country_name
# LIMIT 50;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 50 rows affected.
# [('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2015, Decimal('20.00'), Decimal('33.75'), None),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2016, Decimal('18.02'), Decimal('34.64'), None),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2017, Decimal('18.90'), Decimal('35.64'), Decimal('11.18')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2018, Decimal('18.42'), Decimal('36.69'), None),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2019, Decimal('18.90'), Decimal('37.77'), None),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2020, Decimal('20.14'), Decimal('38.97'), Decimal('11.71')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2015, Decimal('165.98'), Decimal('39.54'), Decimal('11.21')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2016, Decimal('160.03'), Decimal('40.34'), Decimal('10.20')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2017, Decimal('170.10'), Decimal('41.14'), Decimal('12.00')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2018, Decimal('174.91'), Decimal('41.93'), None),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2019, Decimal('171.77'), Decimal('42.71'), None),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2020, Decimal('145.01'), Decimal('43.45'), None),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200.00'), 'American Samoa', 2015, Decimal('0.67'), Decimal('0.05'), None),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200.00'), 'American Samoa', 2016, Decimal('0.67'), Decimal('0.05'), None),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200.00'), 'American Samoa', 2017, Decimal('0.61'), Decimal('0.05'), None),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200.00'), 'American Samoa', 2018, Decimal('0.64'), Decimal('0.05'), None),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200.00'), 'American Samoa', 2019, Decimal('0.65'), Decimal('0.05'), None),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200.00'), 'American Samoa', 2020, Decimal('0.72'), Decimal('0.05'), None),
#  ('Angola', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1246700.00'), 'Angola', 2015, Decimal('87.22'), Decimal('28.13'), None),
#  ('Angola', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1246700.00'), 'Angola', 2016, Decimal('49.84'), Decimal('29.15'), None),
#  ('Angola', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1246700.00'), 'Angola', 2017, Decimal('68.97'), Decimal('30.21'), None),
#  ('Angola', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1246700.00'), 'Angola', 2018, Decimal('77.79'), Decimal('31.27'), None),
#  ('Angola', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1246700.00'), 'Angola', 2019, Decimal('69.31'), Decimal('32.35'), Decimal('16.50')),
#  ('Angola', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1246700.00'), 'Angola', 2020, Decimal('53.62'), Decimal('33.43'), None),
#  ('Anguilla', 'Caribbean', 'Latin America and the Caribbean', None, 'Anguilla', 2015, None, None, None),
#  ('Anguilla', 'Caribbean', 'Latin America and the Caribbean', None, 'Anguilla', 2016, None, None, None),
#  ('Anguilla', 'Caribbean', 'Latin America and the Caribbean', None, 'Anguilla', 2017, None, None, None),
#  ('Antigua and Barbuda', 'Caribbean', 'Latin America and the Caribbean', Decimal('440.00'), 'Antigua and Barbuda', 2015, Decimal('1.34'), Decimal('0.09'), None),
#  ('Antigua and Barbuda', 'Caribbean', 'Latin America and the Caribbean', Decimal('440.00'), 'Antigua and Barbuda', 2016, Decimal('1.44'), Decimal('0.09'), None),
#  ('Antigua and Barbuda', 'Caribbean', 'Latin America and the Caribbean', Decimal('440.00'), 'Antigua and Barbuda', 2017, Decimal('1.47'), Decimal('0.09'), None),
#  ('Argentina', 'South America', 'Latin America and the Caribbean', Decimal('2736690.00'), 'Argentina', 2015, Decimal('594.75'), Decimal('43.13'), None),
#  ('Argentina', 'South America', 'Latin America and the Caribbean', Decimal('2736690.00'), 'Argentina', 2016, Decimal('557.53'), Decimal('43.59'), None),
#  ('Argentina', 'South America', 'Latin America and the Caribbean', Decimal('2736690.00'), 'Argentina', 2017, Decimal('643.63'), Decimal('44.04'), Decimal('8.35')),
#  ('Argentina', 'South America', 'Latin America and the Caribbean', Decimal('2736690.00'), 'Argentina', 2018, Decimal('524.82'), Decimal('44.49'), Decimal('9.22')),
#  ('Argentina', 'South America', 'Latin America and the Caribbean', Decimal('2736690.00'), 'Argentina', 2019, Decimal('447.75'), Decimal('44.94'), Decimal('9.84')),
#  ('Argentina', 'South America', 'Latin America and the Caribbean', Decimal('2736690.00'), 'Argentina', 2020, Decimal('385.54'), Decimal('45.38'), Decimal('11.46')),
#  ('Armenia', 'Western Asia', 'Northern Africa and Western Asia', Decimal('28470.00'), 'Armenia', 2015, Decimal('10.55'), Decimal('2.88'), Decimal('18.26')),
#  ('Armenia', 'Western Asia', 'Northern Africa and Western Asia', Decimal('28470.00'), 'Armenia', 2016, Decimal('10.55'), Decimal('2.87'), Decimal('17.62')),
#  ('Armenia', 'Western Asia', 'Northern Africa and Western Asia', Decimal('28470.00'), 'Armenia', 2017, Decimal('11.53'), Decimal('2.85'), Decimal('17.70')),
#  ('Armenia', 'Western Asia', 'Northern Africa and Western Asia', Decimal('28470.00'), 'Armenia', 2018, Decimal('12.46'), Decimal('2.84'), Decimal('13.21')),
#  ('Armenia', 'Western Asia', 'Northern Africa and Western Asia', Decimal('28470.00'), 'Armenia', 2019, Decimal('13.62'), Decimal('2.82'), Decimal('12.20')),
#  ('Armenia', 'Western Asia', 'Northern Africa and Western Asia', Decimal('28470.00'), 'Armenia', 2020, Decimal('12.64'), Decimal('2.81'), Decimal('12.18')),
#  ('Aruba', 'Caribbean', 'Latin America and the Caribbean', Decimal('180.00'), 'Aruba', 2015, Decimal('2.96'), Decimal('0.10'), None),
#  ('Aruba', 'Caribbean', 'Latin America and the Caribbean', Decimal('180.00'), 'Aruba', 2016, Decimal('2.98'), Decimal('0.10'), None),
#  ('Australia', 'Australia and New Zealand', 'Oceania', Decimal('7690400.00'), 'Australia', 2015, Decimal('1350.62'), Decimal('23.82'), Decimal('6.06')),
#  ('Australia', 'Australia and New Zealand', 'Oceania', Decimal('7690400.00'), 'Australia', 2016, Decimal('1206.54'), Decimal('24.19'), Decimal('5.71')),
#  ('Australia', 'Australia and New Zealand', 'Oceania', Decimal('7690400.00'), 'Australia', 2017, Decimal('1326.52'), Decimal('24.59'), Decimal('5.59')),
#  ('Australia', 'Australia and New Zealand', 'Oceania', Decimal('7690400.00'), 'Australia', 2018, Decimal('1428.29'), Decimal('24.97'), Decimal('5.30')),
#  ('Australia', 'Australia and New Zealand', 'Oceania', Decimal('7690400.00'), 'Australia', 2019, Decimal('1392.23'), Decimal('25.34'), Decimal('5.16')),
#  ('Australia', 'Australia and New Zealand', 'Oceania', Decimal('7690400.00'), 'Australia', 2020, Decimal('1326.90'), Decimal('25.66'), Decimal('6.46'))]

# %% [markdown]
# ### 2. Second `LEFT JOIN`
#
# Combine the previously joined tables with the `Basic_Services` table, again based on the `Country_name` column.

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     Geographic_Location g
# LEFT JOIN
#     Economic_Indicators e
#     ON
#         g.Country_name = e.Country_name
# LEFT JOIN
#     Basic_Services b
#     ON
#         g.Country_name = b.Country_Name
# LIMIT 50;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 50 rows affected.
# [('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2015, Decimal('20.00'), Decimal('33.75'), None, 'Afghanistan', 2015, Decimal('67.00'), Decimal('45.67')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2015, Decimal('20.00'), Decimal('33.75'), None, 'Afghanistan', 2016, Decimal('69.67'), Decimal('47.00')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2015, Decimal('20.00'), Decimal('33.75'), None, 'Afghanistan', 2017, Decimal('72.33'), Decimal('49.33')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2015, Decimal('20.00'), Decimal('33.75'), None, 'Afghanistan', 2018, Decimal('75.33'), Decimal('50.67')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2015, Decimal('20.00'), Decimal('33.75'), None, 'Afghanistan', 2019, Decimal('78.00'), Decimal('52.33')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2015, Decimal('20.00'), Decimal('33.75'), None, 'Afghanistan', 2020, Decimal('80.33'), Decimal('54.00')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2016, Decimal('18.02'), Decimal('34.64'), None, 'Afghanistan', 2015, Decimal('67.00'), Decimal('45.67')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2016, Decimal('18.02'), Decimal('34.64'), None, 'Afghanistan', 2016, Decimal('69.67'), Decimal('47.00')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2016, Decimal('18.02'), Decimal('34.64'), None, 'Afghanistan', 2017, Decimal('72.33'), Decimal('49.33')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2016, Decimal('18.02'), Decimal('34.64'), None, 'Afghanistan', 2018, Decimal('75.33'), Decimal('50.67')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2016, Decimal('18.02'), Decimal('34.64'), None, 'Afghanistan', 2019, Decimal('78.00'), Decimal('52.33')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2016, Decimal('18.02'), Decimal('34.64'), None, 'Afghanistan', 2020, Decimal('80.33'), Decimal('54.00')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2017, Decimal('18.90'), Decimal('35.64'), Decimal('11.18'), 'Afghanistan', 2015, Decimal('67.00'), Decimal('45.67')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2017, Decimal('18.90'), Decimal('35.64'), Decimal('11.18'), 'Afghanistan', 2016, Decimal('69.67'), Decimal('47.00')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2017, Decimal('18.90'), Decimal('35.64'), Decimal('11.18'), 'Afghanistan', 2017, Decimal('72.33'), Decimal('49.33')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2017, Decimal('18.90'), Decimal('35.64'), Decimal('11.18'), 'Afghanistan', 2018, Decimal('75.33'), Decimal('50.67')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2017, Decimal('18.90'), Decimal('35.64'), Decimal('11.18'), 'Afghanistan', 2019, Decimal('78.00'), Decimal('52.33')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2017, Decimal('18.90'), Decimal('35.64'), Decimal('11.18'), 'Afghanistan', 2020, Decimal('80.33'), Decimal('54.00')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2018, Decimal('18.42'), Decimal('36.69'), None, 'Afghanistan', 2015, Decimal('67.00'), Decimal('45.67')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2018, Decimal('18.42'), Decimal('36.69'), None, 'Afghanistan', 2016, Decimal('69.67'), Decimal('47.00')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2018, Decimal('18.42'), Decimal('36.69'), None, 'Afghanistan', 2017, Decimal('72.33'), Decimal('49.33')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2018, Decimal('18.42'), Decimal('36.69'), None, 'Afghanistan', 2018, Decimal('75.33'), Decimal('50.67')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2018, Decimal('18.42'), Decimal('36.69'), None, 'Afghanistan', 2019, Decimal('78.00'), Decimal('52.33')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2018, Decimal('18.42'), Decimal('36.69'), None, 'Afghanistan', 2020, Decimal('80.33'), Decimal('54.00')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2019, Decimal('18.90'), Decimal('37.77'), None, 'Afghanistan', 2015, Decimal('67.00'), Decimal('45.67')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2019, Decimal('18.90'), Decimal('37.77'), None, 'Afghanistan', 2016, Decimal('69.67'), Decimal('47.00')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2019, Decimal('18.90'), Decimal('37.77'), None, 'Afghanistan', 2017, Decimal('72.33'), Decimal('49.33')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2019, Decimal('18.90'), Decimal('37.77'), None, 'Afghanistan', 2018, Decimal('75.33'), Decimal('50.67')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2019, Decimal('18.90'), Decimal('37.77'), None, 'Afghanistan', 2019, Decimal('78.00'), Decimal('52.33')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2019, Decimal('18.90'), Decimal('37.77'), None, 'Afghanistan', 2020, Decimal('80.33'), Decimal('54.00')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2020, Decimal('20.14'), Decimal('38.97'), Decimal('11.71'), 'Afghanistan', 2015, Decimal('67.00'), Decimal('45.67')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2020, Decimal('20.14'), Decimal('38.97'), Decimal('11.71'), 'Afghanistan', 2016, Decimal('69.67'), Decimal('47.00')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2020, Decimal('20.14'), Decimal('38.97'), Decimal('11.71'), 'Afghanistan', 2017, Decimal('72.33'), Decimal('49.33')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2020, Decimal('20.14'), Decimal('38.97'), Decimal('11.71'), 'Afghanistan', 2018, Decimal('75.33'), Decimal('50.67')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2020, Decimal('20.14'), Decimal('38.97'), Decimal('11.71'), 'Afghanistan', 2019, Decimal('78.00'), Decimal('52.33')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2020, Decimal('20.14'), Decimal('38.97'), Decimal('11.71'), 'Afghanistan', 2020, Decimal('80.33'), Decimal('54.00')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2015, Decimal('165.98'), Decimal('39.54'), Decimal('11.21'), 'Algeria', 2015, Decimal('92.00'), Decimal('85.00')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2015, Decimal('165.98'), Decimal('39.54'), Decimal('11.21'), 'Algeria', 2016, Decimal('93.00'), Decimal('85.33')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2015, Decimal('165.98'), Decimal('39.54'), Decimal('11.21'), 'Algeria', 2017, Decimal('93.00'), Decimal('84.67')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2015, Decimal('165.98'), Decimal('39.54'), Decimal('11.21'), 'Algeria', 2018, Decimal('93.00'), Decimal('84.67')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2015, Decimal('165.98'), Decimal('39.54'), Decimal('11.21'), 'Algeria', 2019, Decimal('93.33'), Decimal('84.67')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2015, Decimal('165.98'), Decimal('39.54'), Decimal('11.21'), 'Algeria', 2020, Decimal('93.33'), Decimal('84.33')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2016, Decimal('160.03'), Decimal('40.34'), Decimal('10.20'), 'Algeria', 2015, Decimal('92.00'), Decimal('85.00')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2016, Decimal('160.03'), Decimal('40.34'), Decimal('10.20'), 'Algeria', 2016, Decimal('93.00'), Decimal('85.33')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2016, Decimal('160.03'), Decimal('40.34'), Decimal('10.20'), 'Algeria', 2017, Decimal('93.00'), Decimal('84.67')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2016, Decimal('160.03'), Decimal('40.34'), Decimal('10.20'), 'Algeria', 2018, Decimal('93.00'), Decimal('84.67')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2016, Decimal('160.03'), Decimal('40.34'), Decimal('10.20'), 'Algeria', 2019, Decimal('93.33'), Decimal('84.67')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2016, Decimal('160.03'), Decimal('40.34'), Decimal('10.20'), 'Algeria', 2020, Decimal('93.33'), Decimal('84.33')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2017, Decimal('170.10'), Decimal('41.14'), Decimal('12.00'), 'Algeria', 2015, Decimal('92.00'), Decimal('85.00')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2017, Decimal('170.10'), Decimal('41.14'), Decimal('12.00'), 'Algeria', 2016, Decimal('93.00'), Decimal('85.33'))]

# %% [markdown]
# ### 3. Refine the second `LEFT JOIN`
#
# At first glance, the results of the above query might seem fine, but take a closer look at the `Time_periods`. We can see that they don't align as we would expect.
#
# Refine the second `LEFT JOIN` query by adding an additional condition based on the `Time_period` column.

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     Geographic_Location g
# LEFT JOIN
#     Economic_Indicators e
#     ON
#         g.Country_name = e.Country_name
# LEFT JOIN
#     Basic_Services b
#     ON
#         g.Country_name = b.Country_Name
#     AND
#         e.Time_period = b.Time_period
# LIMIT 50;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 50 rows affected.
# [('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2015, Decimal('20.00'), Decimal('33.75'), None, 'Afghanistan', 2015, Decimal('67.00'), Decimal('45.67')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2016, Decimal('18.02'), Decimal('34.64'), None, 'Afghanistan', 2016, Decimal('69.67'), Decimal('47.00')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2017, Decimal('18.90'), Decimal('35.64'), Decimal('11.18'), 'Afghanistan', 2017, Decimal('72.33'), Decimal('49.33')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2018, Decimal('18.42'), Decimal('36.69'), None, 'Afghanistan', 2018, Decimal('75.33'), Decimal('50.67')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2019, Decimal('18.90'), Decimal('37.77'), None, 'Afghanistan', 2019, Decimal('78.00'), Decimal('52.33')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.00'), 'Afghanistan', 2020, Decimal('20.14'), Decimal('38.97'), Decimal('11.71'), 'Afghanistan', 2020, Decimal('80.33'), Decimal('54.00')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2015, Decimal('165.98'), Decimal('39.54'), Decimal('11.21'), 'Algeria', 2015, Decimal('92.00'), Decimal('85.00')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2016, Decimal('160.03'), Decimal('40.34'), Decimal('10.20'), 'Algeria', 2016, Decimal('93.00'), Decimal('85.33')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2017, Decimal('170.10'), Decimal('41.14'), Decimal('12.00'), 'Algeria', 2017, Decimal('93.00'), Decimal('84.67')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2018, Decimal('174.91'), Decimal('41.93'), None, 'Algeria', 2018, Decimal('93.00'), Decimal('84.67')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2019, Decimal('171.77'), Decimal('42.71'), None, 'Algeria', 2019, Decimal('93.33'), Decimal('84.67')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.00'), 'Algeria', 2020, Decimal('145.01'), Decimal('43.45'), None, 'Algeria', 2020, Decimal('93.33'), Decimal('84.33')),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200.00'), 'American Samoa', 2015, Decimal('0.67'), Decimal('0.05'), None, 'American Samoa', 2015, Decimal('100.00'), Decimal('57.00')),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200.00'), 'American Samoa', 2016, Decimal('0.67'), Decimal('0.05'), None, 'American Samoa', 2016, Decimal('100.00'), Decimal('56.00')),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200.00'), 'American Samoa', 2017, Decimal('0.61'), Decimal('0.05'), None, 'American Samoa', 2017, Decimal('100.00'), Decimal('54.00')),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200.00'), 'American Samoa', 2018, Decimal('0.64'), Decimal('0.05'), None, 'American Samoa', 2018, Decimal('100.00'), Decimal('54.00')),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200.00'), 'American Samoa', 2019, Decimal('0.65'), Decimal('0.05'), None, 'American Samoa', 2019, Decimal('100.00'), Decimal('54.00')),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200.00'), 'American Samoa', 2020, Decimal('0.72'), Decimal('0.05'), None, 'American Samoa', 2020, Decimal('100.00'), Decimal('54.00')),
#  ('Angola', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1246700.00'), 'Angola', 2015, Decimal('87.22'), Decimal('28.13'), None, 'Angola', 2015, Decimal('50.33'), Decimal('43.33')),
#  ('Angola', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1246700.00'), 'Angola', 2016, Decimal('49.84'), Decimal('29.15'), None, 'Angola', 2016, Decimal('51.00'), Decimal('44.67')),
#  ('Angola', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1246700.00'), 'Angola', 2017, Decimal('68.97'), Decimal('30.21'), None, 'Angola', 2017, Decimal('51.33'), Decimal('45.67')),
#  ('Angola', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1246700.00'), 'Angola', 2018, Decimal('77.79'), Decimal('31.27'), None, 'Angola', 2018, Decimal('52.33'), Decimal('46.67')),
#  ('Angola', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1246700.00'), 'Angola', 2019, Decimal('69.31'), Decimal('32.35'), Decimal('16.50'), 'Angola', 2019, Decimal('52.33'), Decimal('46.67')),
#  ('Angola', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1246700.00'), 'Angola', 2020, Decimal('53.62'), Decimal('33.43'), None, 'Angola', 2020, Decimal('52.33'), Decimal('47.00')),
#  ('Anguilla', 'Caribbean', 'Latin America and the Caribbean', None, 'Anguilla', 2015, None, None, None, 'Anguilla', 2015, Decimal('97.00'), Decimal('97.00')),
#  ('Anguilla', 'Caribbean', 'Latin America and the Caribbean', None, 'Anguilla', 2016, None, None, None, 'Anguilla', 2016, Decimal('97.00'), Decimal('97.00')),
#  ('Anguilla', 'Caribbean', 'Latin America and the Caribbean', None, 'Anguilla', 2017, None, None, None, 'Anguilla', 2017, Decimal('97.00'), Decimal('97.00')),
#  ('Antigua and Barbuda', 'Caribbean', 'Latin America and the Caribbean', Decimal('440.00'), 'Antigua and Barbuda', 2015, Decimal('1.34'), Decimal('0.09'), None, 'Antigua and Barbuda', 2015, Decimal('97.00'), Decimal('88.00')),
#  ('Antigua and Barbuda', 'Caribbean', 'Latin America and the Caribbean', Decimal('440.00'), 'Antigua and Barbuda', 2016, Decimal('1.44'), Decimal('0.09'), None, 'Antigua and Barbuda', 2016, Decimal('97.00'), Decimal('88.00')),
#  ('Antigua and Barbuda', 'Caribbean', 'Latin America and the Caribbean', Decimal('440.00'), 'Antigua and Barbuda', 2017, Decimal('1.47'), Decimal('0.09'), None, 'Antigua and Barbuda', 2017, Decimal('97.00'), Decimal('88.00')),
#  ('Argentina', 'South America', 'Latin America and the Caribbean', Decimal('2736690.00'), 'Argentina', 2015, Decimal('594.75'), Decimal('43.13'), None, 'Argentina', 2015, Decimal('97.33'), Decimal('89.67')),
#  ('Argentina', 'South America', 'Latin America and the Caribbean', Decimal('2736690.00'), 'Argentina', 2016, Decimal('557.53'), Decimal('43.59'), None, 'Argentina', 2016, Decimal('97.33'), Decimal('89.67')),
#  ('Argentina', 'South America', 'Latin America and the Caribbean', Decimal('2736690.00'), 'Argentina', 2017, Decimal('643.63'), Decimal('44.04'), Decimal('8.35'), 'Argentina', 2017, Decimal('100.00'), Decimal('97.00')),
#  ('Argentina', 'South America', 'Latin America and the Caribbean', Decimal('2736690.00'), 'Argentina', 2018, Decimal('524.82'), Decimal('44.49'), Decimal('9.22'), 'Argentina', 2018, Decimal('100.00'), Decimal('98.00')),
#  ('Argentina', 'South America', 'Latin America and the Caribbean', Decimal('2736690.00'), 'Argentina', 2019, Decimal('447.75'), Decimal('44.94'), Decimal('9.84'), 'Argentina', 2019, Decimal('100.00'), Decimal('98.00')),
#  ('Argentina', 'South America', 'Latin America and the Caribbean', Decimal('2736690.00'), 'Argentina', 2020, Decimal('385.54'), Decimal('45.38'), Decimal('11.46'), 'Argentina', 2020, Decimal('100.00'), Decimal('99.00')),
#  ('Armenia', 'Western Asia', 'Northern Africa and Western Asia', Decimal('28470.00'), 'Armenia', 2015, Decimal('10.55'), Decimal('2.88'), Decimal('18.26'), 'Armenia', 2015, Decimal('99.67'), Decimal('91.33')),
#  ('Armenia', 'Western Asia', 'Northern Africa and Western Asia', Decimal('28470.00'), 'Armenia', 2016, Decimal('10.55'), Decimal('2.87'), Decimal('17.62'), 'Armenia', 2016, Decimal('99.67'), Decimal('91.67')),
#  ('Armenia', 'Western Asia', 'Northern Africa and Western Asia', Decimal('28470.00'), 'Armenia', 2017, Decimal('11.53'), Decimal('2.85'), Decimal('17.70'), 'Armenia', 2017, Decimal('100.00'), Decimal('92.00')),
#  ('Armenia', 'Western Asia', 'Northern Africa and Western Asia', Decimal('28470.00'), 'Armenia', 2018, Decimal('12.46'), Decimal('2.84'), Decimal('13.21'), 'Armenia', 2018, Decimal('100.00'), Decimal('92.33')),
#  ('Armenia', 'Western Asia', 'Northern Africa and Western Asia', Decimal('28470.00'), 'Armenia', 2019, Decimal('13.62'), Decimal('2.82'), Decimal('12.20'), 'Armenia', 2019, Decimal('100.00'), Decimal('92.33')),
#  ('Armenia', 'Western Asia', 'Northern Africa and Western Asia', Decimal('28470.00'), 'Armenia', 2020, Decimal('12.64'), Decimal('2.81'), Decimal('12.18'), 'Armenia', 2020, Decimal('100.00'), Decimal('92.33')),
#  ('Aruba', 'Caribbean', 'Latin America and the Caribbean', Decimal('180.00'), 'Aruba', 2015, Decimal('2.96'), Decimal('0.10'), None, 'Aruba', 2015, Decimal('98.00'), Decimal('98.00')),
#  ('Aruba', 'Caribbean', 'Latin America and the Caribbean', Decimal('180.00'), 'Aruba', 2016, Decimal('2.98'), Decimal('0.10'), None, 'Aruba', 2016, Decimal('98.00'), Decimal('98.00')),
#  ('Australia', 'Australia and New Zealand', 'Oceania', Decimal('7690400.00'), 'Australia', 2015, Decimal('1350.62'), Decimal('23.82'), Decimal('6.06'), 'Australia', 2015, Decimal('100.00'), Decimal('100.00')),
#  ('Australia', 'Australia and New Zealand', 'Oceania', Decimal('7690400.00'), 'Australia', 2016, Decimal('1206.54'), Decimal('24.19'), Decimal('5.71'), 'Australia', 2016, Decimal('100.00'), Decimal('100.00')),
#  ('Australia', 'Australia and New Zealand', 'Oceania', Decimal('7690400.00'), 'Australia', 2017, Decimal('1326.52'), Decimal('24.59'), Decimal('5.59'), 'Australia', 2017, Decimal('100.00'), Decimal('100.00')),
#  ('Australia', 'Australia and New Zealand', 'Oceania', Decimal('7690400.00'), 'Australia', 2018, Decimal('1428.29'), Decimal('24.97'), Decimal('5.30'), 'Australia', 2018, Decimal('100.00'), Decimal('100.00')),
#  ('Australia', 'Australia and New Zealand', 'Oceania', Decimal('7690400.00'), 'Australia', 2019, Decimal('1392.23'), Decimal('25.34'), Decimal('5.16'), 'Australia', 2019, Decimal('100.00'), Decimal('100.00')),
#  ('Australia', 'Australia and New Zealand', 'Oceania', Decimal('7690400.00'), 'Australia', 2020, Decimal('1326.90'), Decimal('25.66'), Decimal('6.46'), 'Australia', 2020, Decimal('100.00'), Decimal('100.00'))]

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### 1. First `LEFT JOIN`

# %%
# %%sql
#
# SELECT
# 	*
# FROM
# 	united_nations.Geographic_Location as geo
# LEFT JOIN
# 	united_nations.Economic_Indicators as econ
# 	ON geo.Country_name = econ.Country_name
# LIMIT 50;

# %% [markdown]
# With this LEFT JOIN, we will get all the records from the `Geographic_Location` table and only the matching records from the `Economic_Indicators` table. If there is no match, we will still get the data from the `Geographic_Location` table, and the columns from the `Economic_Indicators` table will be `NULL`.

# %% [markdown]
# ### 2. Second `LEFT JOIN`

# %%
# %%sql
#
# SELECT
# 	*
# FROM
# 	united_nations.Geographic_Location as geo
# LEFT JOIN
# 	united_nations.Economic_Indicators as econ
# 	ON geo.Country_name = econ.Country_name
# LEFT JOIN
# 	united_nations.Basic_Services as svc
# 	ON geo.Country_name = svc.Country_name
# LIMIT 20;

# %% [markdown]
# ### 3. Refine second `LEFT JOIN`

# %%
# %%sql
#
# SELECT
# 	*
# FROM
# 	united_nations.Geographic_Location as geo
# LEFT JOIN
# 	united_nations.Economic_Indicators as econ
# 	ON geo.Country_name = econ.Country_name
# LEFT JOIN
# 	united_nations.Basic_Services as svc
# 	ON geo.Country_name = svc.Country_name
# 	AND econ.Time_period = svc.Time_period
# LIMIT 20;

# %% [markdown]
# With the additional condition, we ensure that the `Time_periods` align correctly and we get the desired output.

# %% [markdown]
# ## Summary
#
# This notebook shows how Entity-Relationship Diagrams can help us understand database joins better. We specifically focused on the `LEFT JOIN` technique, which is widely used to combine tables. Additionally, we noticed the importance of picking the right joining strategy, as incorrect joins can lead to inaccurate results.

# %% [markdown]
# #
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/refs/heads/master/ALX_banners/ALX_Navy.png"  style="width:100px"  ;/>
# </div>
